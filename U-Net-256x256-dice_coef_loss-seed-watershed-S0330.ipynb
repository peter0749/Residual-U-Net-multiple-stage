# %% [markdown]
# # Intro
# Hello! This rather quick and dirty kernel shows how to get started on segmenting nuclei using a neural network in Keras.
#
# The architecture used is the so-called [U-Net](https://arxiv.org/abs/1505.04597), which is very common for image segmentation problems such as this. I believe they also have a tendency to work quite well even on small datasets.
#
# Let's get started importing everything we need!

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# Set some parameters
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3
TRAIN_PATH = './stage1_train/'
TEST_PATH = './stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed
# Out:
# /home/peter/virtual_envs/tf_keras/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %% [markdown]
# # Get the data
# Let's first import all the images and associated masks. I downsample both the training and test images to keep things light and manageable, but we need to keep a record of the original sizes of the test images to upsample our predicted masks and create correct run-length encodings later on. There are definitely better ways to handle this, but it works fine for now!

# %%
from skimage.measure import regionprops
import cv2, imutils
import math

# Get and resize train images and masks
X_train = []
Y_train = []
#lsum = 0
#msum = 0
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    X_train.append(img)
    mask = np.zeros(img.shape[:2], dtype=np.uint8)
    mark = np.zeros(img.shape[:2], dtype=np.uint8)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        cnts = cv2.findContours(mask_.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = cnts[0] if imutils.is_cv2() else cnts[1]
        M = cv2.moments(cnts[0])
        if M["m00"] != 0:
            cX = M["m10"] / M["m00"]
            cY = M["m01"] / M["m00"]
        else:
            p = regionprops(mask_, cache=True)[0]
            cY, cX = p.centroid
        r = int(math.ceil( max( img.shape[0], img.shape[1] ) * .01 ))
        cv2.circle(mark, (int(cX), int(cY)), r, 255, -1)
        mask = np.maximum(mask, mask_)
    mark = cv2.GaussianBlur(mark, (3,3), 0)
    #lsum += np.sum(mask)
    #msum += np.sum(mark)
    Y_train.append([mask, mark])

# print(msum / (lsum+msum))

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append(img.shape[:2])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [01:21<00:00,  8.22it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:02<00:00, 28.62it/s]
# Done!

# %% [markdown]
# Let's see if things look all right by drawing some random images and their associated masks.

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix][0]), cmap='gray')
plt.show()
x_copy = X_train[ix].copy()
x_copy[np.squeeze(Y_train[ix][1])>0, :] = 255, 0, 0
plt.imshow(x_copy)
plt.show()

# %% [markdown]
# Seems good!
#
# # Create our Keras metric
#
# Now we try to define the *mean average precision at different intersection over union (IoU) thresholds* metric in Keras. TensorFlow has a mean IoU metric, but it doesn't have any native support for the mean over multiple thresholds, so I tried to implement this. **I'm by no means certain that this implementation is correct, though!** Any assistance in verifying this would be most welcome!
#
# *Update: This implementation is most definitely not correct due to the very large discrepancy between the results reported here and the LB results. It also seems to just increase over time no matter what when you train ... *

# %%
# Define IoU metric
def mean_iou(y_true_, y_pred_):
    y_true = y_true_[...,0]
    y_pred = y_pred_[...,0]
    prec = []
    for t in np.arange(0.5, 1.0, 0.1):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

def mean_iou_marker(y_true_, y_pred_):
    y_true = y_true_[...,1]
    y_pred = y_pred_[...,1]
    prec = []
    for t in np.arange(0.5, 1.0, 0.1):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

def dice_coef(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.*intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + intersection + smooth)

def custom_loss(y_true_, y_pred_):
    alpha = 0.8 # control amount of loss of markers
    
    y_true_hm = y_true_[...,0]
    y_true_mk = y_true_[...,1]
    
    y_pred_hm = y_pred_[...,0]
    y_pred_mk = y_pred_[...,1]
    
    s_marker_loss = 1. - dice_coef(y_true_mk, y_pred_mk)
    s_heatmap_loss= 1. - dice_coef(y_true_hm, y_pred_hm)
    
    losses = alpha * s_marker_loss + (1.-alpha) * s_heatmap_loss
    return losses

# %% [markdown]
# # Build and train our neural network
# Next we build our U-Net model, loosely based on [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf) and very similar to [this repo](https://github.com/jocicmarko/ultrasound-nerve-segmentation) from the Kaggle Ultrasound Nerve Segmentation competition.
#
# ![](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
from keras.layers import Lambda, Add, Activation, UpSampling2D, Dropout
from keras.optimizers import Adam

def build_stage(inputs, last=None, id_='st1'):
    def conv(f, k=3, act='elu'):
        return Conv2D(f, (k, k), activation=act, kernel_initializer='he_normal', padding='same')
    def _incept_conv(inputs, f, dropout=0, chs=[0.15, 0.5, 0.25, 0.1]):
        fs = [] # determine channel number
        for k in chs:
            t = max(int(k*f), 1) # at least 1 channel
            fs.append(t)
        
        fs[1] += f-np.sum(fs) # reminding channels allocate to 3x3 conv
        
        c1x1 = conv(fs[0], 1, act='linear') (inputs)
        c3x3 = conv(max(1, fs[1]//2), 1, act='elu') (inputs)
        c5x5 = conv(max(1, fs[2]//2), 1, act='elu') (inputs)
        cpool= MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same') (inputs)
        
        c3x3 = conv(fs[1], 3, act='linear') (c3x3)
        c5x5 = conv(fs[2], 5, act='linear') (c5x5)
        cpool= conv(fs[3], 1, act='linear') (cpool)
        
        output = concatenate([c1x1, c3x3, c5x5, cpool], axis=-1)
        if dropout>0:
            output = Dropout(dropout) (output)
        return output
    
    def _res_conv(inputs, f, k=3, dropout=0.1): # very simple residual module
        channels = int(inputs.shape[-1])
        
        cs = _incept_conv(inputs, f, dropout=dropout)
        
        if f!=channels:
            t1 = conv(f, 1, 'linear') (inputs) # identity mapping
        else:
            t1 = inputs
        
        out = Add()([t1, cs]) # t1 + c2
        out = Activation('elu') (out)
        return out
    def pool():
        return MaxPooling2D((2, 2))
    def up(inputs, dropout=0):
        upsampled = Conv2DTranspose(int(inputs.shape[-1]), (2, 2), strides=(2, 2), padding='same') (inputs)
        if dropout>0:
            upsampled = Dropout(dropout) (upsampled)
        return upsampled
    
    if last is None:
        c1 = Lambda(lambda x: x / 255) (inputs) # 1st stage input, an image
    else:
        c1 = Add()([inputs, last]) # dimensions of inputs, last are same
    
    c1 = _res_conv(c1, 32, 3)
    o1 = c1
    p1 = pool() (c1)
    
    c2 = _res_conv(p1, 64, 3)
    p2 = pool() (c2)

    c3 = _res_conv(p2, 128, 3)
    p3 = pool() (c3)
    
    c4 = _res_conv(p3, 256, 3)
    p4 = pool() (c4)
    
    c5 = _res_conv(p4, 512, 3)
    p5 = pool() (c5)
    
    c6 = _res_conv(p5, 512, 3, dropout=0.3)
    
    u7 = up (c6, dropout=0.3)
    c7 = concatenate([u7, c5])
    c7 = _res_conv(c7, 512, 3)
    
    u8 = up (c7, dropout=0.25)
    c8 = concatenate([u8, c4])
    c8 = _res_conv(c8, 256, 3)
    
    u9 = up (c8, dropout=0.2)
    c9 = concatenate([u9, c3])
    c9 = _res_conv(c9, 128, 3)
    
    u10 = up (c9, dropout=0.14)
    c10 = concatenate([u10, c2])
    c10 = _res_conv(c10, 64, 3)
    
    u11 = up (c10, dropout=0.1)
    c11 = concatenate([u11, c1])
    c11 = _res_conv(c11, 32, 3)
    
    outputs = Conv2D(2, (1, 1), activation='sigmoid', name=id_+'_out') (c11)
    return outputs, o1

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
out, _ = build_stage(inputs, None, 'st1')

model = Model(inputs=[inputs], outputs=[out])
model.compile(loss=custom_loss, metrics=[mean_iou, mean_iou_marker], optimizer=Adam(lr=5e-5))
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 8)  32          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 3)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 17) 1241        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 256, 8)  808         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 3)  12          max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 32) 0           conv2d_1[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 32) 128         lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 32) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 256, 32) 0           conv2d_7[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 32) 0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 32) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 16) 528         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 8)  264         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 32) 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 9)  297         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 33) 4785        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 16) 3216        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 6)  198         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 64) 0           conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 64) 2112        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 128, 64) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 128, 64) 0           conv2d_14[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 64) 0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 32)   2080        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 16)   1040        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 64)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 19)   1235        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 65)   18785       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 32)   12832       conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 12)   780         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 128)  0           conv2d_15[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 128)  8320        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 128)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 128)  0           conv2d_21[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 128)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 64)   8256        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 32)   4128        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 128)  0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 38)   4902        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 25)   3225        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 256)  0           conv2d_22[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 256)  33024       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 256)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 256)  0           conv2d_28[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 256)  0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 256)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 128)  32896       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 64)   16448       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 256)  0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 76)   19532       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 51)   13107       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 512)  0           conv2d_29[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 512)  131584      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 512)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 512)  0           conv2d_35[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 8, 8, 512)    0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 128)    65664       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 64)     32832       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 8, 8, 512)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 76)     38988       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 257)    296321      conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 128)    204928      conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 51)     26163       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 8, 8, 512)    0           conv2d_36[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 512)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 512)    0           max_pooling2d_10[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 512)  1049088     activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 512)  0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 1024) 0           dropout_7[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 128)  131200      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 64)   65600       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 1024) 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 76)   77900       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 16, 16, 257)  296321      conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 128)  204928      conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 51)   52275       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 512)  0           conv2d_42[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 16, 16, 512)  524800      concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 512)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 512)  0           conv2d_48[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 512)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 512)  1049088     activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32, 32, 512)  0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 768)  0           dropout_9[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 64)   49216       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 32)   24608       concatenate_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 32, 32, 768)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 38)   29222       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 129)  74433       conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 64)   51264       conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 32, 32, 25)   19225       max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 256)  0           conv2d_49[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 32, 32, 256)  196864      concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 256)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 256)  0           conv2d_55[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 256)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 256)  262400      activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64, 64, 256)  0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 64, 64, 384)  0           dropout_11[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 64, 64, 32)   12320       concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 64, 16)   6160        concatenate_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 64, 64, 384)  0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 64, 64, 19)   7315        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 64, 64, 65)   18785       conv2d_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 64, 32)   12832       conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 64, 64, 12)   4620        max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 64, 64, 128)  0           conv2d_56[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 64, 64, 128)  49280       concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64, 64, 128)  0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 128)  0           conv2d_62[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 128)  0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 128 65664       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 128, 128, 128 0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 128, 128, 192 0           dropout_13[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 128, 128, 16) 3088        concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 128, 128, 8)  1544        concatenate_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 128, 128, 192 0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 128, 128, 9)  1737        concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 128, 128, 33) 4785        conv2d_64[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 128, 128, 16) 3216        conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 128, 128, 6)  1158        max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 128, 128, 64) 0           conv2d_63[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 128, 128, 64) 12352       concatenate_13[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 128, 128, 64) 0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 128, 128, 64) 0           conv2d_69[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 64) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 256, 256, 64) 16448       activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 256, 256, 64) 0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 256, 256, 96) 0           dropout_15[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 256, 256, 8)  776         concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 256, 256, 4)  388         concatenate_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 256, 256, 96) 0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 256, 256, 4)  388         concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 256, 256, 17) 1241        conv2d_71[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 256, 256, 8)  808         conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 256, 256, 3)  291         max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 256, 256, 32) 0           conv2d_70[0][0]
#                                                                  conv2d_73[0][0]
#                                                                  conv2d_74[0][0]
#                                                                  conv2d_75[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 256, 256, 32) 3104        concatenate_15[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 256, 256, 32) 0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 256, 256, 32) 0           conv2d_76[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 256, 256, 32) 0           add_11[0][0]
# __________________________________________________________________________________________________
# st1_out (Conv2D)                (None, 256, 256, 2)  66          activation_11[0][0]
# ==================================================================================================
# Total params: 6,004,467
# Trainable params: 6,004,467
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# *Update: Changed to ELU units, added dropout.*
#
# Next we fit the model on the training data, using a validation split of 0.1. We use a small batch size because we have so little data. I recommend using checkpointing and early stopping when training your model. I won't do it here to make things a bit more reproducible (although it's very likely that your results will be different anyway). I'll just train for 10 epochs, which takes around 10 minutes in the Kaggle kernel with the current parameters.
#
# *Update: Added early stopping and checkpointing and increased to 30 epochs.*

# %%
from keras.preprocessing.image import ImageDataGenerator
import cv2

from sklearn.utils import shuffle
def data_generator(data, label, batch_size=4, training=True):
    index = 0
    dat_que = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
    lab_que = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH, 2), dtype=np.bool)
    while True:
        img = data[index%len(data)] # [0,255]
        lab = label[index%len(data)][0]
        marker = label[index%len(data)][1]
        if training:
            if np.random.rand() < .5: # flip vertical
                img = np.flip(img, 0)
                lab = np.flip(lab, 0)
                marker = np.flip(marker, 0)
            if np.random.rand() < .5: # flip horizontal
                img = np.flip(img, 1)
                lab = np.flip(lab, 1)
                marker = np.flip(marker, 1)

            # rotation
            if np.random.rand() < 0.5:
                y, x, _ = img.shape
                h, w = y, x
                img = cv2.copyMakeBorder(img, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                lab = cv2.copyMakeBorder(lab, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                marker = cv2.copyMakeBorder(marker, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                y, x, _ = img.shape
                rotT = np.random.uniform(-15,15)
                M = cv2.getRotationMatrix2D((x/2, y/2), rotT, 1)
                img = cv2.warpAffine(img, M, (x, y))
                lab = cv2.warpAffine(lab, M, (x, y))
                marker = cv2.warpAffine(marker, M, (x, y))
                img = img[h//2:h//2+h,w//2:w//2+w,:]
                lab = lab[h//2:h//2+h,w//2:w//2+w]
                marker = marker[h//2:h//2+h,w//2:w//2+w]

            img = img.astype(np.float32) / 255. # normalize

            # random amplify each channel
            a = .1 # amptitude
            t  = [np.random.uniform(-a,a)]
            t += [np.random.uniform(-a,a)]
            t += [np.random.uniform(-a,a)]
            t = np.array(t)

            img = img * (1. + t) # channel wise amplify
            up = np.random.uniform(0.95, 1.05) # change gamma
            img = img**up * 255. # apply gamma and convert back to range [0,255]
            img = img.astype(np.uint8) # convert back to uint8

            assert img.dtype == np.uint8 ## check type
            assert lab.dtype == np.uint8

            if np.random.rand() < .1: # randomly crop image
                s = np.random.uniform(0.8, 1.2) # random crop scale
                w, h = int(s*IMG_WIDTH), int(s*IMG_HEIGHT)
                paddx = max(0, w-img.shape[1])
                paddy = max(0, h-img.shape[0])
                img = cv2.copyMakeBorder(img, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                lab = cv2.copyMakeBorder(lab, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                marker = cv2.copyMakeBorder(marker, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                cropx = img.shape[1] - w + 1
                cropy = img.shape[0] - h + 1
                offx = np.random.randint(0, cropx)
                offy = np.random.randint(0, cropy)
                img = img[offy:offy+h, offx:offx+w, :]
                lab = lab[offy:offy+h, offx:offx+w]
                marker = marker[offy:offy+h, offx:offx+w]
        ### end of data augmentation ###
        
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        lab = resize(lab, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        marker = resize(marker, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        
        lab[lab<130] = 0
        lab[lab>0] = 1
        
        marker[marker<130] = 0
        marker[marker>0] = 1
        
        dat_que[index%batch_size,:,:,:] = img
        lab_que[index%batch_size,:,:,0] = lab
        lab_que[index%batch_size,:,:,1] = marker
        index = index + 1
        if index%batch_size==0:
            index = 0 if index%len(data)==0 else index
            yield (dat_que, lab_que)
        if training and index%len(data)==0:
            data, label = shuffle(data, label)

from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, shuffle=True)

# Fit model
BS=8
EPOCHS=100
# earlystopper = EarlyStopping(patience=7, verbose=1)
# checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
history = model.fit_generator(data_generator(X_train, Y_train, batch_size=BS, training=True),
                              steps_per_epoch=len(X_train) // BS , epochs=EPOCHS, 
                              validation_data=data_generator(X_val, Y_val, batch_size=BS, training=False), 
                              validation_steps=len(X_val) // BS)
# Out:
# Epoch 1/100
# 75/75 [==============================] - 84s 1s/step - loss: 0.8970 - mean_iou: 0.4055 - mean_iou_marker: 0.3730 - val_loss: 0.8694 - val_mean_iou: 0.4531 - val_mean_iou_marker: 0.3844
# Epoch 2/100
# 75/75 [==============================] - 72s 965ms/step - loss: 0.7911 - mean_iou: 0.4816 - mean_iou_marker: 0.3971 - val_loss: 0.7197 - val_mean_iou: 0.5124 - val_mean_iou_marker: 0.4244
# Epoch 3/100
# 75/75 [==============================] - 73s 971ms/step - loss: 0.6957 - mean_iou: 0.5315 - mean_iou_marker: 0.4443 - val_loss: 0.7197 - val_mean_iou: 0.5485 - val_mean_iou_marker: 0.4599
# Epoch 4/100
# 75/75 [==============================] - 78s 1s/step - loss: 0.6599 - mean_iou: 0.5623 - mean_iou_marker: 0.4712 - val_loss: 0.6528 - val_mean_iou: 0.5742 - val_mean_iou_marker: 0.4809
# Epoch 5/100
# 75/75 [==============================] - 75s 1s/step - loss: 0.6362 - mean_iou: 0.5852 - mean_iou_marker: 0.4888 - val_loss: 0.6154 - val_mean_iou: 0.5963 - val_mean_iou_marker: 0.4958
# Epoch 6/100
# 75/75 [==============================] - 75s 998ms/step - loss: 0.6251 - mean_iou: 0.6065 - mean_iou_marker: 0.5020 - val_loss: 0.6093 - val_mean_iou: 0.6153 - val_mean_iou_marker: 0.5074
# Epoch 7/100
# 75/75 [==============================] - 74s 989ms/step - loss: 0.6192 - mean_iou: 0.6225 - mean_iou_marker: 0.5123 - val_loss: 0.6242 - val_mean_iou: 0.6294 - val_mean_iou_marker: 0.5167
# Epoch 8/100
# 75/75 [==============================] - 73s 978ms/step - loss: 0.6041 - mean_iou: 0.6369 - mean_iou_marker: 0.5207 - val_loss: 0.6536 - val_mean_iou: 0.6427 - val_mean_iou_marker: 0.5244
# Epoch 9/100
# 75/75 [==============================] - 74s 991ms/step - loss: 0.5981 - mean_iou: 0.6480 - mean_iou_marker: 0.5277 - val_loss: 0.6459 - val_mean_iou: 0.6533 - val_mean_iou_marker: 0.5310
# Epoch 10/100
# 75/75 [==============================] - 72s 966ms/step - loss: 0.5876 - mean_iou: 0.6592 - mean_iou_marker: 0.5343 - val_loss: 0.6219 - val_mean_iou: 0.6641 - val_mean_iou_marker: 0.5371
# Epoch 11/100
# 75/75 [==============================] - 74s 986ms/step - loss: 0.5926 - mean_iou: 0.6684 - mean_iou_marker: 0.5398 - val_loss: 0.6528 - val_mean_iou: 0.6725 - val_mean_iou_marker: 0.5424
# Epoch 12/100
# 75/75 [==============================] - 76s 1s/step - loss: 0.5820 - mean_iou: 0.6769 - mean_iou_marker: 0.5448 - val_loss: 0.6481 - val_mean_iou: 0.6814 - val_mean_iou_marker: 0.5472
# Epoch 13/100
# 75/75 [==============================] - 74s 982ms/step - loss: 0.5830 - mean_iou: 0.6853 - mean_iou_marker: 0.5494 - val_loss: 0.6450 - val_mean_iou: 0.6893 - val_mean_iou_marker: 0.5516
# Epoch 14/100
# 75/75 [==============================] - 72s 963ms/step - loss: 0.5830 - mean_iou: 0.6930 - mean_iou_marker: 0.5536 - val_loss: 0.6634 - val_mean_iou: 0.6967 - val_mean_iou_marker: 0.5554
# Epoch 15/100
# 75/75 [==============================] - 72s 966ms/step - loss: 0.5725 - mean_iou: 0.7002 - mean_iou_marker: 0.5574 - val_loss: 0.6139 - val_mean_iou: 0.7039 - val_mean_iou_marker: 0.5592
# Epoch 16/100
# 75/75 [==============================] - 74s 987ms/step - loss: 0.5811 - mean_iou: 0.7072 - mean_iou_marker: 0.5608 - val_loss: 0.5995 - val_mean_iou: 0.7104 - val_mean_iou_marker: 0.5626
# Epoch 17/100
# 75/75 [==============================] - 74s 991ms/step - loss: 0.5716 - mean_iou: 0.7133 - mean_iou_marker: 0.5643 - val_loss: 0.6250 - val_mean_iou: 0.7164 - val_mean_iou_marker: 0.5660
# Epoch 18/100
# 75/75 [==============================] - 73s 976ms/step - loss: 0.5749 - mean_iou: 0.7191 - mean_iou_marker: 0.5674 - val_loss: 0.5791 - val_mean_iou: 0.7218 - val_mean_iou_marker: 0.5689
# Epoch 19/100
# 75/75 [==============================] - 73s 973ms/step - loss: 0.5706 - mean_iou: 0.7244 - mean_iou_marker: 0.5703 - val_loss: 0.5820 - val_mean_iou: 0.7269 - val_mean_iou_marker: 0.5717
# Epoch 20/100
# 75/75 [==============================] - 74s 986ms/step - loss: 0.5694 - mean_iou: 0.7295 - mean_iou_marker: 0.5732 - val_loss: 0.5691 - val_mean_iou: 0.7319 - val_mean_iou_marker: 0.5745
# Epoch 21/100
# 75/75 [==============================] - 73s 974ms/step - loss: 0.5645 - mean_iou: 0.7342 - mean_iou_marker: 0.5758 - val_loss: 0.5394 - val_mean_iou: 0.7362 - val_mean_iou_marker: 0.5772
# Epoch 22/100
# 75/75 [==============================] - 72s 966ms/step - loss: 0.5618 - mean_iou: 0.7385 - mean_iou_marker: 0.5786 - val_loss: 0.5270 - val_mean_iou: 0.7405 - val_mean_iou_marker: 0.5799
# Epoch 23/100
# 75/75 [==============================] - 74s 982ms/step - loss: 0.5631 - mean_iou: 0.7424 - mean_iou_marker: 0.5812 - val_loss: 0.5230 - val_mean_iou: 0.7443 - val_mean_iou_marker: 0.5825
# Epoch 24/100
# 75/75 [==============================] - 73s 971ms/step - loss: 0.5651 - mean_iou: 0.7461 - mean_iou_marker: 0.5836 - val_loss: 0.5269 - val_mean_iou: 0.7479 - val_mean_iou_marker: 0.5848
# Epoch 25/100
# 75/75 [==============================] - 72s 960ms/step - loss: 0.5665 - mean_iou: 0.7497 - mean_iou_marker: 0.5860 - val_loss: 0.5307 - val_mean_iou: 0.7513 - val_mean_iou_marker: 0.5871
# Epoch 26/100
# 75/75 [==============================] - 74s 986ms/step - loss: 0.5612 - mean_iou: 0.7528 - mean_iou_marker: 0.5883 - val_loss: 0.5311 - val_mean_iou: 0.7541 - val_mean_iou_marker: 0.5893
# Epoch 27/100
# 75/75 [==============================] - 73s 978ms/step - loss: 0.5679 - mean_iou: 0.7556 - mean_iou_marker: 0.5903 - val_loss: 0.5443 - val_mean_iou: 0.7572 - val_mean_iou_marker: 0.5912
# Epoch 28/100
# 75/75 [==============================] - 76s 1s/step - loss: 0.5559 - mean_iou: 0.7587 - mean_iou_marker: 0.5923 - val_loss: 0.5432 - val_mean_iou: 0.7601 - val_mean_iou_marker: 0.5933
# Epoch 29/100
# 75/75 [==============================] - 77s 1s/step - loss: 0.5629 - mean_iou: 0.7614 - mean_iou_marker: 0.5942 - val_loss: 0.5773 - val_mean_iou: 0.7626 - val_mean_iou_marker: 0.5951
# Epoch 30/100
# 75/75 [==============================] - 75s 998ms/step - loss: 0.5562 - mean_iou: 0.7640 - mean_iou_marker: 0.5960 - val_loss: 0.5690 - val_mean_iou: 0.7654 - val_mean_iou_marker: 0.5969
# Epoch 31/100
# 75/75 [==============================] - 72s 957ms/step - loss: 0.5574 - mean_iou: 0.7666 - mean_iou_marker: 0.5978 - val_loss: 0.5878 - val_mean_iou: 0.7678 - val_mean_iou_marker: 0.5986
# Epoch 32/100
# 75/75 [==============================] - 71s 949ms/step - loss: 0.5477 - mean_iou: 0.7690 - mean_iou_marker: 0.5995 - val_loss: 0.6104 - val_mean_iou: 0.7701 - val_mean_iou_marker: 0.6003
# Epoch 33/100
# 75/75 [==============================] - 73s 975ms/step - loss: 0.5584 - mean_iou: 0.7712 - mean_iou_marker: 0.6010 - val_loss: 0.5844 - val_mean_iou: 0.7724 - val_mean_iou_marker: 0.6018
# Epoch 34/100
# 75/75 [==============================] - 74s 982ms/step - loss: 0.5549 - mean_iou: 0.7735 - mean_iou_marker: 0.6026 - val_loss: 0.5879 - val_mean_iou: 0.7746 - val_mean_iou_marker: 0.6033
# Epoch 35/100
# 75/75 [==============================] - 74s 983ms/step - loss: 0.5567 - mean_iou: 0.7756 - mean_iou_marker: 0.6040 - val_loss: 0.6159 - val_mean_iou: 0.7767 - val_mean_iou_marker: 0.6046
# Epoch 36/100
# 75/75 [==============================] - 75s 1s/step - loss: 0.5528 - mean_iou: 0.7777 - mean_iou_marker: 0.6053 - val_loss: 0.6018 - val_mean_iou: 0.7787 - val_mean_iou_marker: 0.6059
# Epoch 37/100
# 75/75 [==============================] - 76s 1s/step - loss: 0.5490 - mean_iou: 0.7796 - mean_iou_marker: 0.6067 - val_loss: 0.5869 - val_mean_iou: 0.7806 - val_mean_iou_marker: 0.6074
# Epoch 38/100
# 75/75 [==============================] - 70s 936ms/step - loss: 0.5520 - mean_iou: 0.7815 - mean_iou_marker: 0.6079 - val_loss: 0.5525 - val_mean_iou: 0.7825 - val_mean_iou_marker: 0.6086
# Epoch 39/100
# 75/75 [==============================] - 74s 982ms/step - loss: 0.5462 - mean_iou: 0.7834 - mean_iou_marker: 0.6093 - val_loss: 0.5558 - val_mean_iou: 0.7843 - val_mean_iou_marker: 0.6099
# Epoch 40/100
# 75/75 [==============================] - 71s 947ms/step - loss: 0.5446 - mean_iou: 0.7852 - mean_iou_marker: 0.6106 - val_loss: 0.5387 - val_mean_iou: 0.7861 - val_mean_iou_marker: 0.6112
# Epoch 41/100
# 75/75 [==============================] - 71s 941ms/step - loss: 0.5503 - mean_iou: 0.7870 - mean_iou_marker: 0.6118 - val_loss: 0.5466 - val_mean_iou: 0.7878 - val_mean_iou_marker: 0.6123
# Epoch 42/100
# 75/75 [==============================] - 72s 961ms/step - loss: 0.5351 - mean_iou: 0.7886 - mean_iou_marker: 0.6131 - val_loss: 0.5188 - val_mean_iou: 0.7894 - val_mean_iou_marker: 0.6138
# Epoch 43/100
# 75/75 [==============================] - 73s 972ms/step - loss: 0.5479 - mean_iou: 0.7902 - mean_iou_marker: 0.6144 - val_loss: 0.5145 - val_mean_iou: 0.7909 - val_mean_iou_marker: 0.6150
# Epoch 44/100
# 75/75 [==============================] - 72s 958ms/step - loss: 0.5399 - mean_iou: 0.7917 - mean_iou_marker: 0.6156 - val_loss: 0.4987 - val_mean_iou: 0.7923 - val_mean_iou_marker: 0.6163
# Epoch 45/100
# 75/75 [==============================] - 71s 953ms/step - loss: 0.5395 - mean_iou: 0.7931 - mean_iou_marker: 0.6169 - val_loss: 0.5010 - val_mean_iou: 0.7939 - val_mean_iou_marker: 0.6176
# Epoch 46/100
# 75/75 [==============================] - 78s 1s/step - loss: 0.5488 - mean_iou: 0.7945 - mean_iou_marker: 0.6181 - val_loss: 0.5033 - val_mean_iou: 0.7952 - val_mean_iou_marker: 0.6187
# Epoch 47/100
# 75/75 [==============================] - 76s 1s/step - loss: 0.5435 - mean_iou: 0.7959 - mean_iou_marker: 0.6192 - val_loss: 0.5078 - val_mean_iou: 0.7965 - val_mean_iou_marker: 0.6198
# Epoch 48/100
# 75/75 [==============================] - 72s 957ms/step - loss: 0.5485 - mean_iou: 0.7972 - mean_iou_marker: 0.6204 - val_loss: 0.5161 - val_mean_iou: 0.7978 - val_mean_iou_marker: 0.6209
# Epoch 49/100
# 75/75 [==============================] - 74s 991ms/step - loss: 0.5263 - mean_iou: 0.7984 - mean_iou_marker: 0.6216 - val_loss: 0.5164 - val_mean_iou: 0.7991 - val_mean_iou_marker: 0.6222
# Epoch 50/100
# 75/75 [==============================] - 71s 949ms/step - loss: 0.5500 - mean_iou: 0.7997 - mean_iou_marker: 0.6227 - val_loss: 0.5132 - val_mean_iou: 0.8003 - val_mean_iou_marker: 0.6231
# Epoch 51/100
# 75/75 [==============================] - 70s 933ms/step - loss: 0.5353 - mean_iou: 0.8009 - mean_iou_marker: 0.6237 - val_loss: 0.5070 - val_mean_iou: 0.8015 - val_mean_iou_marker: 0.6242
# Epoch 52/100
# 75/75 [==============================] - 75s 1s/step - loss: 0.5346 - mean_iou: 0.8021 - mean_iou_marker: 0.6247 - val_loss: 0.5494 - val_mean_iou: 0.8026 - val_mean_iou_marker: 0.6252
# Epoch 53/100
# 75/75 [==============================] - 72s 955ms/step - loss: 0.5350 - mean_iou: 0.8032 - mean_iou_marker: 0.6257 - val_loss: 0.5744 - val_mean_iou: 0.8037 - val_mean_iou_marker: 0.6261
# Epoch 54/100
# 75/75 [==============================] - 73s 976ms/step - loss: 0.5322 - mean_iou: 0.8043 - mean_iou_marker: 0.6266 - val_loss: 0.5916 - val_mean_iou: 0.8048 - val_mean_iou_marker: 0.6271
# Epoch 55/100
# 75/75 [==============================] - 72s 957ms/step - loss: 0.5406 - mean_iou: 0.8053 - mean_iou_marker: 0.6275 - val_loss: 0.5815 - val_mean_iou: 0.8058 - val_mean_iou_marker: 0.6279
# Epoch 56/100
# 75/75 [==============================] - 75s 1s/step - loss: 0.5278 - mean_iou: 0.8063 - mean_iou_marker: 0.6284 - val_loss: 0.5759 - val_mean_iou: 0.8068 - val_mean_iou_marker: 0.6289
# Epoch 57/100
# 75/75 [==============================] - 80s 1s/step - loss: 0.5402 - mean_iou: 0.8073 - mean_iou_marker: 0.6292 - val_loss: 0.5662 - val_mean_iou: 0.8078 - val_mean_iou_marker: 0.6296
# Epoch 58/100
# 75/75 [==============================] - 71s 942ms/step - loss: 0.5285 - mean_iou: 0.8083 - mean_iou_marker: 0.6301 - val_loss: 0.5504 - val_mean_iou: 0.8088 - val_mean_iou_marker: 0.6306
# Epoch 59/100
# 75/75 [==============================] - 73s 972ms/step - loss: 0.5392 - mean_iou: 0.8093 - mean_iou_marker: 0.6309 - val_loss: 0.5508 - val_mean_iou: 0.8097 - val_mean_iou_marker: 0.6313
# Epoch 60/100
# 75/75 [==============================] - 75s 1s/step - loss: 0.5246 - mean_iou: 0.8102 - mean_iou_marker: 0.6318 - val_loss: 0.5587 - val_mean_iou: 0.8107 - val_mean_iou_marker: 0.6322
# Epoch 61/100
# 75/75 [==============================] - 74s 980ms/step - loss: 0.5356 - mean_iou: 0.8111 - mean_iou_marker: 0.6326 - val_loss: 0.5155 - val_mean_iou: 0.8116 - val_mean_iou_marker: 0.6330
# Epoch 62/100
# 75/75 [==============================] - 69s 918ms/step - loss: 0.5371 - mean_iou: 0.8120 - mean_iou_marker: 0.6333 - val_loss: 0.5355 - val_mean_iou: 0.8124 - val_mean_iou_marker: 0.6337
# Epoch 63/100
# 75/75 [==============================] - 76s 1s/step - loss: 0.5312 - mean_iou: 0.8128 - mean_iou_marker: 0.6341 - val_loss: 0.5132 - val_mean_iou: 0.8132 - val_mean_iou_marker: 0.6345
# Epoch 64/100
# 75/75 [==============================] - 72s 961ms/step - loss: 0.5317 - mean_iou: 0.8137 - mean_iou_marker: 0.6349 - val_loss: 0.5172 - val_mean_iou: 0.8141 - val_mean_iou_marker: 0.6353
# Epoch 65/100
# 75/75 [==============================] - 73s 970ms/step - loss: 0.5335 - mean_iou: 0.8145 - mean_iou_marker: 0.6356 - val_loss: 0.4965 - val_mean_iou: 0.8149 - val_mean_iou_marker: 0.6360
# Epoch 66/100
# 75/75 [==============================] - 72s 959ms/step - loss: 0.5280 - mean_iou: 0.8153 - mean_iou_marker: 0.6364 - val_loss: 0.4901 - val_mean_iou: 0.8157 - val_mean_iou_marker: 0.6368
# Epoch 67/100
# 75/75 [==============================] - 71s 949ms/step - loss: 0.5260 - mean_iou: 0.8161 - mean_iou_marker: 0.6372 - val_loss: 0.4991 - val_mean_iou: 0.8166 - val_mean_iou_marker: 0.6376
# Epoch 68/100
# 75/75 [==============================] - 73s 970ms/step - loss: 0.5315 - mean_iou: 0.8169 - mean_iou_marker: 0.6380 - val_loss: 0.4858 - val_mean_iou: 0.8173 - val_mean_iou_marker: 0.6384
# Epoch 69/100
# 75/75 [==============================] - 74s 993ms/step - loss: 0.5213 - mean_iou: 0.8177 - mean_iou_marker: 0.6387 - val_loss: 0.5066 - val_mean_iou: 0.8181 - val_mean_iou_marker: 0.6391
# Epoch 70/100
# 75/75 [==============================] - 73s 976ms/step - loss: 0.5441 - mean_iou: 0.8185 - mean_iou_marker: 0.6394 - val_loss: 0.5041 - val_mean_iou: 0.8188 - val_mean_iou_marker: 0.6397
# Epoch 71/100
# 75/75 [==============================] - 72s 957ms/step - loss: 0.5174 - mean_iou: 0.8192 - mean_iou_marker: 0.6401 - val_loss: 0.5039 - val_mean_iou: 0.8195 - val_mean_iou_marker: 0.6405
# Epoch 72/100
# 75/75 [==============================] - 71s 952ms/step - loss: 0.5284 - mean_iou: 0.8199 - mean_iou_marker: 0.6408 - val_loss: 0.5029 - val_mean_iou: 0.8202 - val_mean_iou_marker: 0.6412
# Epoch 73/100
# 75/75 [==============================] - 71s 949ms/step - loss: 0.5359 - mean_iou: 0.8206 - mean_iou_marker: 0.6415 - val_loss: 0.5187 - val_mean_iou: 0.8210 - val_mean_iou_marker: 0.6418
# Epoch 74/100
# 75/75 [==============================] - 72s 961ms/step - loss: 0.5307 - mean_iou: 0.8213 - mean_iou_marker: 0.6422 - val_loss: 0.5126 - val_mean_iou: 0.8216 - val_mean_iou_marker: 0.6425
# Epoch 75/100
# 75/75 [==============================] - 75s 994ms/step - loss: 0.5318 - mean_iou: 0.8220 - mean_iou_marker: 0.6428 - val_loss: 0.5703 - val_mean_iou: 0.8222 - val_mean_iou_marker: 0.6431
# Epoch 76/100
# 75/75 [==============================] - 70s 927ms/step - loss: 0.5236 - mean_iou: 0.8226 - mean_iou_marker: 0.6434 - val_loss: 0.5899 - val_mean_iou: 0.8229 - val_mean_iou_marker: 0.6437
# Epoch 77/100
# 75/75 [==============================] - 76s 1s/step - loss: 0.5202 - mean_iou: 0.8232 - mean_iou_marker: 0.6440 - val_loss: 0.5741 - val_mean_iou: 0.8235 - val_mean_iou_marker: 0.6443
# Epoch 78/100
# 75/75 [==============================] - 70s 935ms/step - loss: 0.5261 - mean_iou: 0.8238 - mean_iou_marker: 0.6446 - val_loss: 0.5659 - val_mean_iou: 0.8241 - val_mean_iou_marker: 0.6449
# Epoch 79/100
# 75/75 [==============================] - 74s 981ms/step - loss: 0.5281 - mean_iou: 0.8243 - mean_iou_marker: 0.6452 - val_loss: 0.5434 - val_mean_iou: 0.8246 - val_mean_iou_marker: 0.6455
# Epoch 80/100
# 75/75 [==============================] - 70s 928ms/step - loss: 0.5389 - mean_iou: 0.8249 - mean_iou_marker: 0.6457 - val_loss: 0.5329 - val_mean_iou: 0.8252 - val_mean_iou_marker: 0.6459
# Epoch 81/100
# 75/75 [==============================] - 73s 970ms/step - loss: 0.5239 - mean_iou: 0.8255 - mean_iou_marker: 0.6462 - val_loss: 0.5218 - val_mean_iou: 0.8259 - val_mean_iou_marker: 0.6465
# Epoch 82/100
# 75/75 [==============================] - 71s 940ms/step - loss: 0.5142 - mean_iou: 0.8262 - mean_iou_marker: 0.6468 - val_loss: 0.5207 - val_mean_iou: 0.8265 - val_mean_iou_marker: 0.6471
# Epoch 83/100
# 75/75 [==============================] - 72s 963ms/step - loss: 0.5409 - mean_iou: 0.8268 - mean_iou_marker: 0.6473 - val_loss: 0.5713 - val_mean_iou: 0.8270 - val_mean_iou_marker: 0.6475
# Epoch 84/100
# 75/75 [==============================] - 72s 963ms/step - loss: 0.5236 - mean_iou: 0.8273 - mean_iou_marker: 0.6478 - val_loss: 0.4990 - val_mean_iou: 0.8276 - val_mean_iou_marker: 0.6481
# Epoch 85/100
# 75/75 [==============================] - 73s 977ms/step - loss: 0.5252 - mean_iou: 0.8279 - mean_iou_marker: 0.6484 - val_loss: 0.4996 - val_mean_iou: 0.8282 - val_mean_iou_marker: 0.6486
# Epoch 86/100
# 75/75 [==============================] - 69s 917ms/step - loss: 0.5225 - mean_iou: 0.8285 - mean_iou_marker: 0.6489 - val_loss: 0.5047 - val_mean_iou: 0.8288 - val_mean_iou_marker: 0.6492
# Epoch 87/100
# 75/75 [==============================] - 75s 997ms/step - loss: 0.5126 - mean_iou: 0.8291 - mean_iou_marker: 0.6495 - val_loss: 0.4906 - val_mean_iou: 0.8293 - val_mean_iou_marker: 0.6498
# Epoch 88/100
# 75/75 [==============================] - 71s 944ms/step - loss: 0.5195 - mean_iou: 0.8296 - mean_iou_marker: 0.6501 - val_loss: 0.4913 - val_mean_iou: 0.8298 - val_mean_iou_marker: 0.6504
# Epoch 89/100
# 75/75 [==============================] - 73s 973ms/step - loss: 0.5254 - mean_iou: 0.8300 - mean_iou_marker: 0.6506 - val_loss: 0.4818 - val_mean_iou: 0.8303 - val_mean_iou_marker: 0.6509
# Epoch 90/100
# 75/75 [==============================] - 71s 951ms/step - loss: 0.5194 - mean_iou: 0.8305 - mean_iou_marker: 0.6511 - val_loss: 0.4715 - val_mean_iou: 0.8307 - val_mean_iou_marker: 0.6514
# Epoch 91/100
# 75/75 [==============================] - 73s 978ms/step - loss: 0.5088 - mean_iou: 0.8310 - mean_iou_marker: 0.6517 - val_loss: 0.4951 - val_mean_iou: 0.8312 - val_mean_iou_marker: 0.6521
# Epoch 92/100
# 75/75 [==============================] - 70s 937ms/step - loss: 0.5146 - mean_iou: 0.8315 - mean_iou_marker: 0.6523 - val_loss: 0.4902 - val_mean_iou: 0.8317 - val_mean_iou_marker: 0.6526
# Epoch 93/100
# 75/75 [==============================] - 74s 992ms/step - loss: 0.5073 - mean_iou: 0.8319 - mean_iou_marker: 0.6529 - val_loss: 0.4720 - val_mean_iou: 0.8322 - val_mean_iou_marker: 0.6532
# Epoch 94/100
# 75/75 [==============================] - 72s 954ms/step - loss: 0.5066 - mean_iou: 0.8324 - mean_iou_marker: 0.6535 - val_loss: 0.4820 - val_mean_iou: 0.8326 - val_mean_iou_marker: 0.6538
# Epoch 95/100
# 75/75 [==============================] - 71s 947ms/step - loss: 0.5076 - mean_iou: 0.8329 - mean_iou_marker: 0.6541 - val_loss: 0.4833 - val_mean_iou: 0.8331 - val_mean_iou_marker: 0.6544
# Epoch 96/100
# 75/75 [==============================] - 74s 991ms/step - loss: 0.5101 - mean_iou: 0.8333 - mean_iou_marker: 0.6548 - val_loss: 0.4946 - val_mean_iou: 0.8335 - val_mean_iou_marker: 0.6550
# Epoch 97/100
# 75/75 [==============================] - 69s 921ms/step - loss: 0.5044 - mean_iou: 0.8338 - mean_iou_marker: 0.6554 - val_loss: 0.5271 - val_mean_iou: 0.8340 - val_mean_iou_marker: 0.6556
# Epoch 98/100
# 75/75 [==============================] - 71s 949ms/step - loss: 0.5028 - mean_iou: 0.8342 - mean_iou_marker: 0.6559 - val_loss: 0.5190 - val_mean_iou: 0.8344 - val_mean_iou_marker: 0.6562
# Epoch 99/100
# 75/75 [==============================] - 70s 934ms/step - loss: 0.5034 - mean_iou: 0.8345 - mean_iou_marker: 0.6564 - val_loss: 0.5149 - val_mean_iou: 0.8347 - val_mean_iou_marker: 0.6567
# Epoch 100/100
# 75/75 [==============================] - 72s 966ms/step - loss: 0.5089 - mean_iou: 0.8349 - mean_iou_marker: 0.6570 - val_loss: 0.5116 - val_mean_iou: 0.8351 - val_mean_iou_marker: 0.6573

# %%
model.save('model.h5')

# %%
plt.plot(history.history['mean_iou'])
plt.plot(history.history['val_mean_iou'])
plt.title('model mean_iou')
plt.ylabel('mean_iou')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['mean_iou_marker'])
plt.plot(history.history['val_mean_iou_marker'])
plt.title('model mean_iou_marker')
plt.ylabel('mean_iou_marker')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper right')
plt.show()

# %% [markdown]
# All right, looks good! Loss seems to be a bit erratic, though. I'll leave it to you to improve the model architecture and parameters!
#
# # Make predictions
#
# Let's make predictions both on the test set, the val set and the train set (as a sanity check). Remember to load the best saved model if you've used early stopping and checkpointing.

# %%
from skimage.morphology import closing, square, remove_small_objects
from skimage.segmentation import clear_border

# Predict on train, val and test
# model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou, 'custom_loss': custom_loss, 'mean_iou_marker': mean_iou_marker, 'dice_coef': dice_coef})
preds_train = model.predict_generator(data_generator(X_train, Y_train, batch_size=1, training=False), steps=len(X_train), verbose=1)
preds_val = model.predict_generator(data_generator(X_val, Y_val, batch_size=1, training=False), steps=len(X_val), verbose=1)
preds_test = model.predict(X_test, verbose=1)

preds_train, preds_train_marker = preds_train[...,0], preds_train[...,1]
preds_val, preds_val_marker = preds_val[...,0], preds_val[...,1]
preds_test, preds_test_marker = preds_test[...,0], preds_test[...,1]

# Threshold predictions
preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
preds_train_marker_t = (preds_train_marker > 0.5).astype(np.uint8)
preds_val_marker_t = (preds_val_marker > 0.5).astype(np.uint8)

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append((resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True),
                                 resize(np.squeeze(preds_test_marker[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True)
                                ))
# Out:
# 603/603 [==============================] - 34s 57ms/step
# 67/67 [==============================] - 4s 54ms/step
# 65/65 [==============================] - 1s 22ms/step

# %%
from scipy import ndimage as ndi
from skimage.morphology import watershed

# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def lb(image, marker):
    if np.sum(image) < np.sum(marker):
        image = marker
    else:
        marker = np.array((marker==1) & (image==1))
    distance = ndi.distance_transform_edt(image)
    markers = ndi.label(marker)[0]
    labels = watershed(-distance, markers, mask=image)
    if np.sum(labels) == 0:
        labels[0,0] = 1
    return labels

def prob_to_rles(x, marker, cutoff=0.5, cutoff_marker=0.5):
    lab_img = lb(x > cutoff, marker > cutoff_marker)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
print(ix)
shape = Y_train[ix][0].shape[:2]
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix][0]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_t[ix]), shape))
plt.show()
plt.imshow(np.squeeze(Y_train[ix][1]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_marker_t[ix]), shape))
plt.show()
lab = lb(preds_train_t[ix], preds_train_marker_t[ix])
plt.imshow(lab)
plt.show()
# Out:
# 415

# %% [markdown]
# The model is at least able to fit to the training data! Certainly a lot of room for improvement even here, but a decent start. How about the validation data?

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
print(ix)
shape = Y_val[ix][0].shape[:2]
plt.imshow(X_val[ix])
plt.show()
plt.imshow(np.squeeze(Y_val[ix][0]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_t[ix]), shape))
plt.show()
plt.imshow(np.squeeze(Y_val[ix][1]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_marker_t[ix]), shape))
plt.show()
lab = lb(preds_val_t[ix], preds_val_marker_t[ix])
plt.imshow(lab)
plt.show()
# Out:
# 64

# %% [markdown]
# Not too shabby! Definitely needs some more training and tweaking.
#
# # Encode and submit our results
#
# Now it's time to submit our results. I've stolen [this](https://www.kaggle.com/rakhlin/fast-run-length-encoding-python) excellent implementation of run-length encoding.

# %% [markdown]
# Let's iterate over the test IDs and generate run-length encodings for each seperate mask identified by skimage ...

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(preds_test_upsampled[n][0], preds_test_upsampled[n][1]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %% [markdown]
# ... and then finally create our submission!

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)

# %% [markdown]
# This scored 0.233 on the LB for me. That was with version 2 of this notebook; be aware that the results from the neural network are extremely erratic and vary greatly from run to run (version 3 is significantly worse, for example). Version 7 scores 0.277!
#
# You should easily be able to stabilize and improve the results just by changing a few parameters, tweaking the architecture a little bit and training longer with early stopping.
#
# **Have fun!**
#
# LB score history:
# - Version 7: 0.277 LB

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)
