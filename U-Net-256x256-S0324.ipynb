# %% [markdown]
# # Intro
# Hello! This rather quick and dirty kernel shows how to get started on segmenting nuclei using a neural network in Keras.
#
# The architecture used is the so-called [U-Net](https://arxiv.org/abs/1505.04597), which is very common for image segmentation problems such as this. I believe they also have a tendency to work quite well even on small datasets.
#
# Let's get started importing everything we need!

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# Set some parameters
IMG_WIDTH = 256
IMG_HEIGHT = 256
IMG_CHANNELS = 3
TRAIN_PATH = './stage1_train/'
TEST_PATH = './stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed
# Out:
# /home/peter/virtual_envs/tf_keras/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %% [markdown]
# # Get the data
# Let's first import all the images and associated masks. I downsample both the training and test images to keep things light and manageable, but we need to keep a record of the original sizes of the test images to upsample our predicted masks and create correct run-length encodings later on. There are definitely better ways to handle this, but it works fine for now!

# %%
# Get and resize train images and masks
X_train = []
Y_train = []
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    X_train.append(img)
    mask = np.zeros(img.shape[:2], dtype=np.uint8)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask = np.maximum(mask, mask_)
    Y_train.append(mask)

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [01:04<00:00, 10.45it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:02<00:00, 28.71it/s]
# Done!

# %% [markdown]
# Let's see if things look all right by drawing some random images and their associated masks.

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix]))
plt.show()

# %% [markdown]
# Seems good!
#
# # Create our Keras metric
#
# Now we try to define the *mean average precision at different intersection over union (IoU) thresholds* metric in Keras. TensorFlow has a mean IoU metric, but it doesn't have any native support for the mean over multiple thresholds, so I tried to implement this. **I'm by no means certain that this implementation is correct, though!** Any assistance in verifying this would be most welcome!
#
# *Update: This implementation is most definitely not correct due to the very large discrepancy between the results reported here and the LB results. It also seems to just increase over time no matter what when you train ... *

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.1):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %% [markdown]
# # Build and train our neural network
# Next we build our U-Net model, loosely based on [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf) and very similar to [this repo](https://github.com/jocicmarko/ultrasound-nerve-segmentation) from the Kaggle Ultrasound Nerve Segmentation competition.
#
# ![](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
from keras.layers import Lambda, Add, Activation, UpSampling2D, Dropout

def build_stage(inputs, last=None, id_='st1'):
    def conv(f, k=3, act='elu'):
        return Conv2D(f, (k, k), activation=act, kernel_initializer='he_normal', padding='same')
    def _incept_conv(inputs, f, dropout=0, chs=[0.15, 0.5, 0.25, 0.1]):
        fs = [] # determine channel number
        for k in chs:
            t = max(int(k*f), 1) # at least 1 channel
            fs.append(t)
        
        fs[1] += f-np.sum(fs) # reminding channels allocate to 3x3 conv
        
        c1x1 = conv(fs[0], 1, act='linear') (inputs)
        c3x3 = conv(max(1, fs[1]//2), 1, act='elu') (inputs)
        c5x5 = conv(max(1, fs[2]//2), 1, act='elu') (inputs)
        cpool= MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same') (inputs)
        
        c3x3 = conv(fs[1], 3, act='linear') (c3x3)
        c5x5 = conv(fs[2], 5, act='linear') (c5x5)
        cpool= conv(fs[3], 1, act='linear') (cpool)
        
        output = concatenate([c1x1, c3x3, c5x5, cpool], axis=-1)
        if dropout>0:
            output = Dropout(dropout) (output)
        return output
    
    def _res_conv(inputs, f, k=3, dropout=0.1): # very simple residual module
        channels = int(inputs.shape[-1])
        
        cs = _incept_conv(inputs, f, dropout=dropout)
        
        if f!=channels:
            t1 = conv(f, 1, 'linear') (inputs) # identity mapping
        else:
            t1 = inputs
        
        out = Add()([t1, cs]) # t1 + c2
        out = Activation('elu') (out)
        return out
    def pool():
        return MaxPooling2D((2, 2))
    def up(inputs, dropout=0):
        upsampled = Conv2DTranspose(int(inputs.shape[-1]), (2, 2), strides=(2, 2), padding='same') (inputs)
        if dropout>0:
            upsampled = Dropout(dropout) (upsampled)
        return upsampled
    
    if last is None:
        c1 = Lambda(lambda x: x / 255) (inputs) # 1st stage input, an image
    else:
        c1 = Add()([inputs, last]) # dimensions of inputs, last are same
    
    c1 = _res_conv(c1, 16, 3)
    o1 = c1
    p1 = pool() (c1)
    
    c2 = _res_conv(p1, 32, 3)
    p2 = pool() (c2)

    c3 = _res_conv(p2, 64, 3)
    p3 = pool() (c3)
    
    c4 = _res_conv(p3, 128, 3)
    p4 = pool() (c4)
    
    c5 = _res_conv(p4, 256, 3)
    p5 = pool() (c5)
    
    c6 = _res_conv(p5, 512, 3, dropout=0.25)
    
    u7 = up (c6, dropout=0.2)
    c7 = concatenate([u7, c5])
    c7 = _res_conv(c7, 256, 3)
    
    u8 = up (c7, dropout=0.2)
    c8 = concatenate([u8, c4])
    c8 = _res_conv(c8, 128, 3)
    
    u9 = up (c8, dropout=0.2)
    c9 = concatenate([u9, c3])
    c9 = _res_conv(c9, 64, 3)
    
    u10 = up (c9, dropout=0.1)
    c10 = concatenate([u10, c2])
    c10 = _res_conv(c10, 32, 3)
    
    u11 = up (c10, dropout=0.1)
    c11 = concatenate([u11, c1])
    c11 = _res_conv(c11, 16, 3, dropout=0.1)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid', name=id_+'_out') (c11)
    return outputs, o1

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
out, _ = build_stage(inputs, None, 'st1')

model = Model(inputs=[inputs], outputs=[out])
model.compile(loss='binary_crossentropy', metrics=[mean_iou], optimizer='adam')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 256, 256, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 2)  8           lambda_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 3)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 2)  8           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 9)  333         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 256, 256, 4)  204         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 1)  4           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 256, 256, 16) 0           conv2d_1[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 16) 64          lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 256, 256, 16) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 256, 16) 0           conv2d_7[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 256, 256, 16) 0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 16) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 128, 128, 8)  136         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 128, 128, 4)  68          max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 128, 128, 16) 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 128, 128, 4)  68          max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 128, 128, 17) 1241        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 128, 128, 8)  808         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 3)  51          max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 32) 0           conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 32) 544         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128, 128, 32) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 128, 32) 0           conv2d_14[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 128, 128, 32) 0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 32)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 16)   528         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 64, 64, 8)    264         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 32)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 9)    297         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 64, 64, 33)   4785        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 64, 64, 16)   3216        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 64, 64, 6)    198         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 64)   0           conv2d_15[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 64, 64, 64)   2112        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64, 64, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 64)   0           conv2d_21[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64, 64, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 32)   2080        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 16)   1040        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 19)   1235        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 65)   18785       conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 32)   12832       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 12)   780         max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 128)  0           conv2d_22[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 128)  8320        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 32, 128)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 128)  0           conv2d_28[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 128)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 64)   8256        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 32)   4128        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 128)  0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 38)   4902        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 129)  74433       conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 16, 16, 64)   51264       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 25)   3225        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 256)  0           conv2d_29[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 256)  33024       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 256)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 256)  0           conv2d_35[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 8, 8, 256)    0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 128)    32896       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 64)     16448       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 8, 8, 256)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 76)     19532       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 257)    296321      conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 128)    204928      conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 51)     13107       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 8, 8, 512)    0           conv2d_36[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 512)    131584      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 8, 8, 512)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 8, 8, 512)    0           conv2d_42[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 8, 8, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 512)  1049088     activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 16, 16, 512)  0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16, 16, 768)  0           dropout_7[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 16, 16, 64)   49216       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 16, 16, 32)   24608       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 16, 16, 768)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 16, 16, 38)   29222       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 16, 16, 129)  74433       conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 16, 16, 64)   51264       conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 16, 16, 25)   19225       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 16, 16, 256)  0           conv2d_43[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 256)  196864      concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 16, 16, 256)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 256)  0           conv2d_49[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 256)  262400      activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 32, 32, 256)  0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 384)  0           dropout_9[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 32)   12320       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 16)   6160        concatenate_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 32, 32, 384)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 19)   7315        concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 65)   18785       conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 32, 32, 32)   12832       conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 32, 32, 12)   4620        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 128)  0           conv2d_50[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 32, 32, 128)  49280       concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 128)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 32, 32, 128)  0           conv2d_56[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 128)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 128)  65664       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 64, 64, 128)  0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 64, 64, 192)  0           dropout_11[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 64, 64, 16)   3088        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 64, 64, 8)    1544        concatenate_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 64, 64, 192)  0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 64, 64, 9)    1737        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 64, 64, 33)   4785        conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 64, 64, 16)   3216        conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 64, 64, 6)    1158        max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 64, 64, 64)   0           conv2d_57[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 64, 64, 64)   12352       concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 64, 64, 64)   0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 64, 64, 64)   0           conv2d_63[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 64) 16448       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 128, 128, 64) 0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 128, 128, 96) 0           dropout_13[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 128, 128, 8)  776         concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 128, 128, 4)  388         concatenate_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 128, 128, 96) 0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 128, 128, 4)  388         concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 128, 128, 17) 1241        conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 128, 128, 8)  808         conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 128, 128, 3)  291         max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 128, 128, 32) 0           conv2d_64[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
#                                                                  conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 128, 128, 32) 3104        concatenate_13[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 128, 128, 32) 0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 128, 128, 32) 0           conv2d_70[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 128, 128, 32) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 256, 256, 32) 4128        activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 256, 256, 32) 0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 256, 256, 48) 0           dropout_15[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 256, 256, 4)  196         concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 256, 256, 2)  98          concatenate_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 256, 256, 48) 0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 256, 256, 2)  98          concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 256, 256, 9)  333         conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 256, 256, 4)  204         conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 256, 256, 1)  49          max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 256, 256, 16) 0           conv2d_71[0][0]
#                                                                  conv2d_74[0][0]
#                                                                  conv2d_75[0][0]
#                                                                  conv2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 256, 256, 16) 784         concatenate_15[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 256, 256, 16) 0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 256, 256, 16) 0           conv2d_77[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 256, 256, 16) 0           add_11[0][0]
# __________________________________________________________________________________________________
# st1_out (Conv2D)                (None, 256, 256, 1)  17          activation_11[0][0]
# ==================================================================================================
# Total params: 2,944,600
# Trainable params: 2,944,600
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# *Update: Changed to ELU units, added dropout.*
#
# Next we fit the model on the training data, using a validation split of 0.1. We use a small batch size because we have so little data. I recommend using checkpointing and early stopping when training your model. I won't do it here to make things a bit more reproducible (although it's very likely that your results will be different anyway). I'll just train for 10 epochs, which takes around 10 minutes in the Kaggle kernel with the current parameters.
#
# *Update: Added early stopping and checkpointing and increased to 30 epochs.*

# %%
from keras.preprocessing.image import ImageDataGenerator
import cv2

from sklearn.utils import shuffle
def data_generator(data, label, batch_size=4, training=True):
    index = 0
    dat_que = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
    lab_que = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    while True:
        img = data[index%len(data)] # [0,255]
        lab = label[index%len(data)]
        if training:
            if np.random.rand() < .5: # flip vertical
                img = np.flip(img, 0)
                lab = np.flip(lab, 0)
            if np.random.rand() < .5: # flip horizontal
                img = np.flip(img, 1)
                lab = np.flip(lab, 1)

            # rotation
            if np.random.rand() < 0.5:
                y, x, _ = img.shape
                h, w = y, x
                img = cv2.copyMakeBorder(img, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                lab = cv2.copyMakeBorder(lab, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                y, x, _ = img.shape
                rotT = np.random.uniform(-15,15)
                M = cv2.getRotationMatrix2D((x/2, y/2), rotT, 1)
                img = cv2.warpAffine(img, M, (x, y))
                lab = cv2.warpAffine(lab, M, (x, y))
                img = img[h//2:h//2+h,w//2:w//2+w,:]
                lab = lab[h//2:h//2+h,w//2:w//2+w]

            img = img.astype(np.float32) / 255. # normalize

            # random amplify each channel
            a = .1 # amptitude
            t  = [np.random.uniform(-a,a)]
            t += [np.random.uniform(-a,a)]
            t += [np.random.uniform(-a,a)]
            t = np.array(t)

            img = img * (1. + t) # channel wise amplify
            up = np.random.uniform(0.95, 1.05) # change gamma
            img = img**up * 255. # apply gamma and convert back to range [0,255]
            img = img.astype(np.uint8) # convert back to uint8

            assert img.dtype == np.uint8 ## check type
            assert lab.dtype == np.uint8

            if np.random.rand() < .1: # randomly crop image
                s = np.random.uniform(0.8, 1.2) # random crop scale
                w, h = int(s*IMG_WIDTH), int(s*IMG_HEIGHT)
                paddx = max(0, w-img.shape[1])
                paddy = max(0, h-img.shape[0])
                img = cv2.copyMakeBorder(img, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                lab = cv2.copyMakeBorder(lab, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                cropx = img.shape[1] - w + 1
                cropy = img.shape[0] - h + 1
                offx = np.random.randint(0, cropx)
                offy = np.random.randint(0, cropy)
                img = img[offy:offy+h, offx:offx+w, :]
                lab = lab[offy:offy+h, offx:offx+w]
        ### end of data augmentation ###
        
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        lab = resize(lab, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        
        lab[lab<130] = 0
        lab[lab>0] = 1
        
        dat_que[index%batch_size,:,:,:] = img
        lab_que[index%batch_size,:,:,0] = lab
        index = index + 1
        if index%batch_size==0:
            index = 0 if index%len(data)==0 else index
            yield (dat_que, lab_que)
        if training and index%len(data)==0:
            data, label = shuffle(data, label)

from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, shuffle=True)

# Fit model
BS=8
EPOCHS=60
# earlystopper = EarlyStopping(patience=7, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
history = model.fit_generator(data_generator(X_train, Y_train, batch_size=BS, training=True),
                              steps_per_epoch=len(X_train) // BS , epochs=EPOCHS, 
                              validation_data=data_generator(X_val, Y_val, batch_size=BS, training=False), 
                              validation_steps=len(X_val) // BS,
                    callbacks=[checkpointer])
# Out:
# Epoch 1/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.2791 - mean_iou: 0.4745
# Epoch 00001: val_loss improved from inf to 0.10536, saving model to model-dsbowl2018-1.h5
# 75/75 [==============================] - 81s 1s/step - loss: 0.2777 - mean_iou: 0.4759 - val_loss: 0.1054 - val_mean_iou: 0.5817
# Epoch 2/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.1269 - mean_iou: 0.6450
# Epoch 00002: val_loss improved from 0.10536 to 0.09642, saving model to model-dsbowl2018-1.h5
# 75/75 [==============================] - 57s 755ms/step - loss: 0.1271 - mean_iou: 0.6455 - val_loss: 0.0964 - val_mean_iou: 0.6843
# Epoch 3/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.1106 - mean_iou: 0.7063
# Epoch 00003: val_loss improved from 0.09642 to 0.09146, saving model to model-dsbowl2018-1.h5
# 75/75 [==============================] - 61s 820ms/step - loss: 0.1106 - mean_iou: 0.7065 - val_loss: 0.0915 - val_mean_iou: 0.7243
# Epoch 4/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0918 - mean_iou: 0.7392
# Epoch 00004: val_loss improved from 0.09146 to 0.05899, saving model to model-dsbowl2018-1.h5
# 75/75 [==============================] - 62s 833ms/step - loss: 0.0919 - mean_iou: 0.7394 - val_loss: 0.0590 - val_mean_iou: 0.7521
# Epoch 5/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0893 - mean_iou: 0.7609
# Epoch 00005: val_loss did not improve
# 75/75 [==============================] - 61s 816ms/step - loss: 0.0891 - mean_iou: 0.7610 - val_loss: 0.0614 - val_mean_iou: 0.7695
# Epoch 6/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0841 - mean_iou: 0.7768
# Epoch 00006: val_loss did not improve
# 75/75 [==============================] - 61s 808ms/step - loss: 0.0835 - mean_iou: 0.7768 - val_loss: 0.0689 - val_mean_iou: 0.7829
# Epoch 7/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0843 - mean_iou: 0.7873
# Epoch 00007: val_loss did not improve
# 75/75 [==============================] - 63s 839ms/step - loss: 0.0840 - mean_iou: 0.7874 - val_loss: 0.0760 - val_mean_iou: 0.7919
# Epoch 8/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0875 - mean_iou: 0.7956
# Epoch 00008: val_loss did not improve
# 75/75 [==============================] - 63s 834ms/step - loss: 0.0872 - mean_iou: 0.7956 - val_loss: 0.1137 - val_mean_iou: 0.7991
# Epoch 9/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0813 - mean_iou: 0.8024
# Epoch 00009: val_loss did not improve
# 75/75 [==============================] - 62s 823ms/step - loss: 0.0815 - mean_iou: 0.8024 - val_loss: 0.0918 - val_mean_iou: 0.8048
# Epoch 10/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0810 - mean_iou: 0.8070
# Epoch 00010: val_loss did not improve
# 75/75 [==============================] - 62s 830ms/step - loss: 0.0810 - mean_iou: 0.8070 - val_loss: 0.0885 - val_mean_iou: 0.8092
# Epoch 11/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0786 - mean_iou: 0.8115
# Epoch 00011: val_loss did not improve
# 75/75 [==============================] - 61s 818ms/step - loss: 0.0780 - mean_iou: 0.8115 - val_loss: 0.0829 - val_mean_iou: 0.8134
# Epoch 12/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0764 - mean_iou: 0.8155
# Epoch 00012: val_loss did not improve
# 75/75 [==============================] - 61s 820ms/step - loss: 0.0766 - mean_iou: 0.8155 - val_loss: 0.0704 - val_mean_iou: 0.8173
# Epoch 13/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0731 - mean_iou: 0.8189
# Epoch 00013: val_loss did not improve
# 75/75 [==============================] - 63s 839ms/step - loss: 0.0736 - mean_iou: 0.8190 - val_loss: 0.0620 - val_mean_iou: 0.8205
# Epoch 14/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0745 - mean_iou: 0.8219
# Epoch 00014: val_loss did not improve
# 75/75 [==============================] - 62s 826ms/step - loss: 0.0742 - mean_iou: 0.8219 - val_loss: 0.0890 - val_mean_iou: 0.8233
# Epoch 15/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0747 - mean_iou: 0.8244
# Epoch 00015: val_loss did not improve
# 75/75 [==============================] - 61s 817ms/step - loss: 0.0748 - mean_iou: 0.8244 - val_loss: 0.0695 - val_mean_iou: 0.8257
# Epoch 16/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0720 - mean_iou: 0.8268
# Epoch 00016: val_loss improved from 0.05899 to 0.05607, saving model to model-dsbowl2018-1.h5
# 75/75 [==============================] - 62s 827ms/step - loss: 0.0723 - mean_iou: 0.8268 - val_loss: 0.0561 - val_mean_iou: 0.8279
# Epoch 17/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0773 - mean_iou: 0.8287
# Epoch 00017: val_loss improved from 0.05607 to 0.05285, saving model to model-dsbowl2018-1.h5
# 75/75 [==============================] - 62s 831ms/step - loss: 0.0768 - mean_iou: 0.8288 - val_loss: 0.0529 - val_mean_iou: 0.8295
# Epoch 18/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0695 - mean_iou: 0.8306
# Epoch 00018: val_loss did not improve
# 75/75 [==============================] - 61s 809ms/step - loss: 0.0695 - mean_iou: 0.8306 - val_loss: 0.0539 - val_mean_iou: 0.8316
# Epoch 19/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0704 - mean_iou: 0.8323
# Epoch 00019: val_loss did not improve
# 75/75 [==============================] - 62s 820ms/step - loss: 0.0708 - mean_iou: 0.8323 - val_loss: 0.0562 - val_mean_iou: 0.8333
# Epoch 20/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0760 - mean_iou: 0.8341
# Epoch 00020: val_loss did not improve
# 75/75 [==============================] - 62s 823ms/step - loss: 0.0767 - mean_iou: 0.8341 - val_loss: 0.0929 - val_mean_iou: 0.8346
# Epoch 21/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0739 - mean_iou: 0.8351
# Epoch 00021: val_loss did not improve
# 75/75 [==============================] - 61s 816ms/step - loss: 0.0743 - mean_iou: 0.8351 - val_loss: 0.0579 - val_mean_iou: 0.8357
# Epoch 22/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0745 - mean_iou: 0.8363
# Epoch 00022: val_loss did not improve
# 75/75 [==============================] - 62s 828ms/step - loss: 0.0742 - mean_iou: 0.8363 - val_loss: 0.0611 - val_mean_iou: 0.8369
# Epoch 23/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0663 - mean_iou: 0.8377
# Epoch 00023: val_loss did not improve
# 75/75 [==============================] - 61s 819ms/step - loss: 0.0664 - mean_iou: 0.8377 - val_loss: 0.0659 - val_mean_iou: 0.8384
# Epoch 24/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0733 - mean_iou: 0.8390
# Epoch 00024: val_loss did not improve
# 75/75 [==============================] - 62s 820ms/step - loss: 0.0733 - mean_iou: 0.8390 - val_loss: 0.0641 - val_mean_iou: 0.8395
# Epoch 25/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0693 - mean_iou: 0.8400
# Epoch 00025: val_loss improved from 0.05285 to 0.05155, saving model to model-dsbowl2018-1.h5
# 75/75 [==============================] - 62s 827ms/step - loss: 0.0695 - mean_iou: 0.8400 - val_loss: 0.0516 - val_mean_iou: 0.8405
# Epoch 26/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0747 - mean_iou: 0.8409
# Epoch 00026: val_loss improved from 0.05155 to 0.04718, saving model to model-dsbowl2018-1.h5
# 75/75 [==============================] - 63s 836ms/step - loss: 0.0744 - mean_iou: 0.8409 - val_loss: 0.0472 - val_mean_iou: 0.8412
# Epoch 27/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0693 - mean_iou: 0.8418
# Epoch 00027: val_loss improved from 0.04718 to 0.04551, saving model to model-dsbowl2018-1.h5
# 75/75 [==============================] - 61s 819ms/step - loss: 0.0696 - mean_iou: 0.8418 - val_loss: 0.0455 - val_mean_iou: 0.8423
# Epoch 28/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0750 - mean_iou: 0.8427
# Epoch 00028: val_loss did not improve
# 75/75 [==============================] - 63s 836ms/step - loss: 0.0745 - mean_iou: 0.8427 - val_loss: 0.0533 - val_mean_iou: 0.8428
# Epoch 29/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0690 - mean_iou: 0.8432
# Epoch 00029: val_loss did not improve
# 75/75 [==============================] - 61s 816ms/step - loss: 0.0697 - mean_iou: 0.8432 - val_loss: 0.1043 - val_mean_iou: 0.8435
# Epoch 30/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0777 - mean_iou: 0.8437
# Epoch 00030: val_loss did not improve
# 75/75 [==============================] - 61s 807ms/step - loss: 0.0771 - mean_iou: 0.8437 - val_loss: 0.0711 - val_mean_iou: 0.8439
# Epoch 31/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0659 - mean_iou: 0.8444
# Epoch 00031: val_loss did not improve
# 75/75 [==============================] - 63s 839ms/step - loss: 0.0661 - mean_iou: 0.8444 - val_loss: 0.1114 - val_mean_iou: 0.8447
# Epoch 32/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0700 - mean_iou: 0.8450
# Epoch 00032: val_loss did not improve
# 75/75 [==============================] - 60s 800ms/step - loss: 0.0700 - mean_iou: 0.8450 - val_loss: 0.0727 - val_mean_iou: 0.8453
# Epoch 33/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0651 - mean_iou: 0.8457
# Epoch 00033: val_loss did not improve
# 75/75 [==============================] - 61s 810ms/step - loss: 0.0650 - mean_iou: 0.8457 - val_loss: 0.0766 - val_mean_iou: 0.8462
# Epoch 34/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0710 - mean_iou: 0.8465
# Epoch 00034: val_loss did not improve
# 75/75 [==============================] - 64s 850ms/step - loss: 0.0712 - mean_iou: 0.8465 - val_loss: 0.0701 - val_mean_iou: 0.8467
# Epoch 35/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0667 - mean_iou: 0.8468
# Epoch 00035: val_loss did not improve
# 75/75 [==============================] - 62s 828ms/step - loss: 0.0679 - mean_iou: 0.8468 - val_loss: 0.0618 - val_mean_iou: 0.8472
# Epoch 36/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0684 - mean_iou: 0.8475
# Epoch 00036: val_loss did not improve
# 75/75 [==============================] - 61s 807ms/step - loss: 0.0679 - mean_iou: 0.8475 - val_loss: 0.0999 - val_mean_iou: 0.8479
# Epoch 37/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0669 - mean_iou: 0.8482
# Epoch 00037: val_loss did not improve
# 75/75 [==============================] - 61s 816ms/step - loss: 0.0671 - mean_iou: 0.8482 - val_loss: 0.0487 - val_mean_iou: 0.8484
# Epoch 38/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0633 - mean_iou: 0.8488
# Epoch 00038: val_loss did not improve
# 75/75 [==============================] - 60s 803ms/step - loss: 0.0632 - mean_iou: 0.8488 - val_loss: 0.0503 - val_mean_iou: 0.8491
# Epoch 39/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0642 - mean_iou: 0.8494
# Epoch 00039: val_loss did not improve
# 75/75 [==============================] - 63s 834ms/step - loss: 0.0641 - mean_iou: 0.8494 - val_loss: 0.0559 - val_mean_iou: 0.8497
# Epoch 40/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0664 - mean_iou: 0.8500
# Epoch 00040: val_loss did not improve
# 75/75 [==============================] - 61s 807ms/step - loss: 0.0672 - mean_iou: 0.8500 - val_loss: 0.0495 - val_mean_iou: 0.8503
# Epoch 41/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0640 - mean_iou: 0.8506
# Epoch 00041: val_loss did not improve
# 75/75 [==============================] - 62s 820ms/step - loss: 0.0640 - mean_iou: 0.8506 - val_loss: 0.0511 - val_mean_iou: 0.8509
# Epoch 42/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0655 - mean_iou: 0.8511
# Epoch 00042: val_loss did not improve
# 75/75 [==============================] - 61s 819ms/step - loss: 0.0651 - mean_iou: 0.8511 - val_loss: 0.0583 - val_mean_iou: 0.8513
# Epoch 43/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0613 - mean_iou: 0.8517
# Epoch 00043: val_loss did not improve
# 75/75 [==============================] - 60s 806ms/step - loss: 0.0620 - mean_iou: 0.8517 - val_loss: 0.0526 - val_mean_iou: 0.8519
# Epoch 44/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0631 - mean_iou: 0.8522
# Epoch 00044: val_loss did not improve
# 75/75 [==============================] - 61s 807ms/step - loss: 0.0626 - mean_iou: 0.8522 - val_loss: 0.0532 - val_mean_iou: 0.8525
# Epoch 45/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0688 - mean_iou: 0.8526
# Epoch 00045: val_loss did not improve
# 75/75 [==============================] - 64s 847ms/step - loss: 0.0684 - mean_iou: 0.8526 - val_loss: 0.0567 - val_mean_iou: 0.8528
# Epoch 46/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0640 - mean_iou: 0.8531
# Epoch 00046: val_loss did not improve
# 75/75 [==============================] - 62s 822ms/step - loss: 0.0642 - mean_iou: 0.8531 - val_loss: 0.0763 - val_mean_iou: 0.8533
# Epoch 47/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0613 - mean_iou: 0.8536
# Epoch 00047: val_loss did not improve
# 75/75 [==============================] - 60s 803ms/step - loss: 0.0615 - mean_iou: 0.8536 - val_loss: 0.0502 - val_mean_iou: 0.8539
# Epoch 48/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0633 - mean_iou: 0.8541
# Epoch 00048: val_loss did not improve
# 75/75 [==============================] - 61s 820ms/step - loss: 0.0630 - mean_iou: 0.8541 - val_loss: 0.0523 - val_mean_iou: 0.8544
# Epoch 49/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0635 - mean_iou: 0.8546
# Epoch 00049: val_loss improved from 0.04551 to 0.04070, saving model to model-dsbowl2018-1.h5
# 75/75 [==============================] - 62s 827ms/step - loss: 0.0632 - mean_iou: 0.8546 - val_loss: 0.0407 - val_mean_iou: 0.8549
# Epoch 50/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0616 - mean_iou: 0.8551
# Epoch 00050: val_loss did not improve
# 75/75 [==============================] - 65s 871ms/step - loss: 0.0619 - mean_iou: 0.8551 - val_loss: 0.0423 - val_mean_iou: 0.8554
# Epoch 51/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0659 - mean_iou: 0.8556
# Epoch 00051: val_loss did not improve
# 75/75 [==============================] - 67s 888ms/step - loss: 0.0657 - mean_iou: 0.8556 - val_loss: 0.0550 - val_mean_iou: 0.8557
# Epoch 52/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0633 - mean_iou: 0.8559
# Epoch 00052: val_loss did not improve
# 75/75 [==============================] - 65s 862ms/step - loss: 0.0630 - mean_iou: 0.8559 - val_loss: 0.0695 - val_mean_iou: 0.8562
# Epoch 53/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0609 - mean_iou: 0.8563
# Epoch 00053: val_loss did not improve
# 75/75 [==============================] - 64s 851ms/step - loss: 0.0608 - mean_iou: 0.8563 - val_loss: 0.0660 - val_mean_iou: 0.8565
# Epoch 54/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0620 - mean_iou: 0.8567
# Epoch 00054: val_loss did not improve
# 75/75 [==============================] - 61s 811ms/step - loss: 0.0619 - mean_iou: 0.8567 - val_loss: 0.0781 - val_mean_iou: 0.8569
# Epoch 55/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0628 - mean_iou: 0.8571
# Epoch 00055: val_loss did not improve
# 75/75 [==============================] - 60s 804ms/step - loss: 0.0632 - mean_iou: 0.8571 - val_loss: 0.0653 - val_mean_iou: 0.8573
# Epoch 56/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0654 - mean_iou: 0.8575
# Epoch 00056: val_loss did not improve
# 75/75 [==============================] - 63s 841ms/step - loss: 0.0653 - mean_iou: 0.8575 - val_loss: 0.0567 - val_mean_iou: 0.8577
# Epoch 57/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0638 - mean_iou: 0.8578
# Epoch 00057: val_loss did not improve
# 75/75 [==============================] - 62s 830ms/step - loss: 0.0637 - mean_iou: 0.8578 - val_loss: 0.0664 - val_mean_iou: 0.8580
# Epoch 58/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0597 - mean_iou: 0.8582
# Epoch 00058: val_loss did not improve
# 75/75 [==============================] - 61s 813ms/step - loss: 0.0593 - mean_iou: 0.8582 - val_loss: 0.0526 - val_mean_iou: 0.8584
# Epoch 59/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0612 - mean_iou: 0.8585
# Epoch 00059: val_loss did not improve
# 75/75 [==============================] - 60s 803ms/step - loss: 0.0609 - mean_iou: 0.8585 - val_loss: 0.0722 - val_mean_iou: 0.8587
# Epoch 60/60
# 74/75 [============================>.] - ETA: 0s - loss: 0.0629 - mean_iou: 0.8588
# Epoch 00060: val_loss did not improve
# 75/75 [==============================] - 62s 822ms/step - loss: 0.0634 - mean_iou: 0.8588 - val_loss: 0.0482 - val_mean_iou: 0.8590

# %%
plt.plot(history.history['mean_iou'])
plt.plot(history.history['val_mean_iou'])
plt.title('model mean_iou')
plt.ylabel('mean_iou')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper right')
plt.show()

# %% [markdown]
# All right, looks good! Loss seems to be a bit erratic, though. I'll leave it to you to improve the model architecture and parameters!
#
# # Make predictions
#
# Let's make predictions both on the test set, the val set and the train set (as a sanity check). Remember to load the best saved model if you've used early stopping and checkpointing.

# %%
from skimage.morphology import closing, square, remove_small_objects
from skimage.segmentation import clear_border

# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict_generator(data_generator(X_train, Y_train, batch_size=1, training=False), steps=len(X_train), verbose=1)
preds_val = model.predict_generator(data_generator(X_val, Y_val, batch_size=1, training=False), steps=len(X_val), verbose=1)
preds_test = model.predict(X_test, verbose=1)

def cleaning(imgs):
    for i, img in enumerate(imgs):
        img = np.squeeze(img)
        imgs[i,:,:,0] = remove_small_objects(img, min_size=4)
    return imgs

# Threshold predictions
preds_train_t = cleaning((preds_train > 0.5).astype(np.uint8))
preds_val_t = cleaning((preds_val > 0.5).astype(np.uint8))
preds_test_t = cleaning((preds_test > 0.5).astype(np.uint8))

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 603/603 [==============================] - 27s 45ms/step
# 67/67 [==============================] - 3s 46ms/step
# 65/65 [==============================] - 1s 13ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
print(ix)
shape = Y_train[ix].shape[:2]
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_t[ix]), shape))
plt.show()
# Out:
# 379

# %% [markdown]
# The model is at least able to fit to the training data! Certainly a lot of room for improvement even here, but a decent start. How about the validation data?

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
print(ix)
shape = Y_val[ix].shape[:2]
plt.imshow(X_val[ix])
plt.show()
plt.imshow(np.squeeze(Y_val[ix]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_t[ix]), shape))
plt.show()
# Out:
# 21

# %% [markdown]
# Not too shabby! Definitely needs some more training and tweaking.
#
# # Encode and submit our results
#
# Now it's time to submit our results. I've stolen [this](https://www.kaggle.com/rakhlin/fast-run-length-encoding-python) excellent implementation of run-length encoding.

# %%
# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %% [markdown]
# Let's iterate over the test IDs and generate run-length encodings for each seperate mask identified by skimage ...

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(preds_test_upsampled[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %% [markdown]
# ... and then finally create our submission!

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)

# %% [markdown]
# This scored 0.233 on the LB for me. That was with version 2 of this notebook; be aware that the results from the neural network are extremely erratic and vary greatly from run to run (version 3 is significantly worse, for example). Version 7 scores 0.277!
#
# You should easily be able to stabilize and improve the results just by changing a few parameters, tweaking the architecture a little bit and training longer with early stopping.
#
# **Have fun!**
#
# LB score history:
# - Version 7: 0.277 LB

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)
