# %% [markdown]
# # Intro
# Hello! This rather quick and dirty kernel shows how to get started on segmenting nuclei using a neural network in Keras.
#
# The architecture used is the so-called [U-Net](https://arxiv.org/abs/1505.04597), which is very common for image segmentation problems such as this. I believe they also have a tendency to work quite well even on small datasets.
#
# Let's get started importing everything we need!

# %%
import os
import sys
import random
import warnings

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from tqdm import tqdm
from itertools import chain
from skimage.io import imread, imshow, imread_collection, concatenate_images
from skimage.transform import resize
from skimage.morphology import label

from keras.models import Model, load_model
from keras.layers import Input
from keras.layers.core import Dropout, Lambda
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend as K

import tensorflow as tf

# Set some parameters
IMG_WIDTH = 224
IMG_HEIGHT = 224
IMG_CHANNELS = 3
TRAIN_PATH = './input/stage1_train/'
TEST_PATH = './input/stage1_test/'

warnings.filterwarnings('ignore', category=UserWarning, module='skimage')
seed = 42
random.seed = seed
np.random.seed = seed
# Out:
# /home/peter/virtual_envs/tf_keras/lib/python3.5/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Get train and test IDs
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

# %% [markdown]
# # Get the data
# Let's first import all the images and associated masks. I downsample both the training and test images to keep things light and manageable, but we need to keep a record of the original sizes of the test images to upsample our predicted masks and create correct run-length encodings later on. There are definitely better ways to handle this, but it works fine for now!

# %%
# Get and resize train images and masks
X_train = []
Y_train = []
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(train_ids), total=len(train_ids)):
    path = TRAIN_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    X_train.append(img)
    mask = np.zeros(img.shape[:2], dtype=np.uint8)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask = np.maximum(mask, mask_)
    Y_train.append(mask)

# Get and resize test images
X_test = np.zeros((len(test_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
sizes_test = []
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in tqdm(enumerate(test_ids), total=len(test_ids)):
    path = TEST_PATH + id_
    img = imread(path + '/images/' + id_ + '.png')[:,:,:IMG_CHANNELS]
    sizes_test.append([img.shape[0], img.shape[1]])
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_test[n] = img

print('Done!')
# Out:
# Getting and resizing train images and masks ...
# 100%|██████████| 670/670 [01:04<00:00, 10.33it/s]
# Getting and resizing test images ...
# 100%|██████████| 65/65 [00:02<00:00, 27.04it/s]
# Done!

# %% [markdown]
# Let's see if things look all right by drawing some random images and their associated masks.

# %%
# Check if training data looks all right
ix = random.randint(0, len(train_ids))
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix]))
plt.show()

# %% [markdown]
# Seems good!
#
# # Create our Keras metric
#
# Now we try to define the *mean average precision at different intersection over union (IoU) thresholds* metric in Keras. TensorFlow has a mean IoU metric, but it doesn't have any native support for the mean over multiple thresholds, so I tried to implement this. **I'm by no means certain that this implementation is correct, though!** Any assistance in verifying this would be most welcome!
#
# *Update: This implementation is most definitely not correct due to the very large discrepancy between the results reported here and the LB results. It also seems to just increase over time no matter what when you train ... *

# %%
# Define IoU metric
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.1):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %% [markdown]
# # Build and train our neural network
# Next we build our U-Net model, loosely based on [U-Net: Convolutional Networks for Biomedical Image Segmentation](https://arxiv.org/pdf/1505.04597.pdf) and very similar to [this repo](https://github.com/jocicmarko/ultrasound-nerve-segmentation) from the Kaggle Ultrasound Nerve Segmentation competition.
#
# ![](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
from keras.layers import Lambda, Add, Activation, UpSampling2D, Dropout

def build_stage(inputs, last=None, id_='st1'):
    def conv(f, k=3, act='elu'):
        return Conv2D(f, (k, k), activation=act, kernel_initializer='he_normal', padding='same')
    def _incept_conv(inputs, f, dropout=0, chs=[0.15, 0.5, 0.25, 0.1]):
        fs = [] # determine channel number
        for k in chs:
            t = max(int(k*f), 1) # at least 1 channel
            fs.append(t)
        
        fs[1] += f-np.sum(fs) # reminding channels allocate to 3x3 conv
        
        c1x1 = conv(fs[0], 1, act='linear') (inputs)
        c3x3 = conv(max(1, fs[1]//2), 1, act='elu') (inputs)
        c5x5 = conv(max(1, fs[2]//2), 1, act='elu') (inputs)
        cpool= MaxPooling2D(pool_size=(3, 3), strides=(1, 1), padding='same') (inputs)
        
        c3x3 = conv(fs[1], 3, act='linear') (c3x3)
        c5x5 = conv(fs[2], 5, act='linear') (c5x5)
        cpool= conv(fs[3], 1, act='linear') (cpool)
        
        output = concatenate([c1x1, c3x3, c5x5, cpool], axis=-1)
        if dropout>0:
            output = Dropout(dropout) (output)
        return output
    
    def _res_conv(inputs, f, k=3, dropout=0.1): # very simple residual module
        channels = int(inputs.shape[-1])
        
        cs = _incept_conv(inputs, f, dropout=dropout)
        
        if f!=channels:
            t1 = conv(f, 1, 'linear') (inputs) # identity mapping
        else:
            t1 = inputs
        
        out = Add()([t1, cs]) # t1 + c2
        out = Activation('elu') (out)
        return out
    def pool():
        return MaxPooling2D((2, 2))
    def up(inputs, dropout=0):
        upsampled = Conv2DTranspose(int(inputs.shape[-1]), (2, 2), strides=(2, 2), padding='same') (inputs)
        if dropout>0:
            upsampled = Dropout(dropout) (upsampled)
        return upsampled
    
    if last is None:
        c1 = Lambda(lambda x: x / 255) (inputs) # 1st stage input, an image
    else:
        c1 = Add()([inputs, last]) # dimensions of inputs, last are same
    
    c1 = _res_conv(c1, 16, 3)
    o1 = c1
    p1 = pool() (c1)
    
    c2 = _res_conv(p1, 32, 3)
    p2 = pool() (c2)

    c3 = _res_conv(p2, 64, 3)
    p3 = pool() (c3)
    
    c4 = _res_conv(p3, 128, 3)
    p4 = pool() (c4)
    
    c5 = _res_conv(p4, 256, 3)
    p5 = pool() (c5)
    
    c6 = _res_conv(p5, 512, 3, dropout=0.25)
    
    u7 = up (c6, dropout=0.2)
    c7 = concatenate([u7, c5])
    c7 = _res_conv(c7, 256, 3)
    
    u8 = up (c7, dropout=0.2)
    c8 = concatenate([u8, c4])
    c8 = _res_conv(c8, 128, 3)
    
    u9 = up (c8, dropout=0.2)
    c9 = concatenate([u9, c3])
    c9 = _res_conv(c9, 64, 3)
    
    u10 = up (c9, dropout=0.1)
    c10 = concatenate([u10, c2])
    c10 = _res_conv(c10, 32, 3)
    
    u11 = up (c10, dropout=0.1)
    c11 = concatenate([u11, c1])
    c11 = _res_conv(c11, 16, 3, dropout=0.1)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid', name=id_+'_out') (c11)
    return outputs, o1

inputs = Input((IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS))
out, _ = build_stage(inputs, None, 'st1')

model = Model(inputs=[inputs], outputs=[out])
model.compile(loss='binary_crossentropy', metrics=[mean_iou], optimizer='adam')
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 224, 224, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 4)  16          lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 224, 224, 2)  8           lambda_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 224, 224, 3)  0           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 2)  8           lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 224, 224, 9)  333         conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 224, 224, 4)  204         conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 224, 224, 1)  4           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 224, 224, 16) 0           conv2d_1[0][0]
#                                                                  conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 224, 224, 16) 64          lambda_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 224, 224, 16) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 224, 224, 16) 0           conv2d_7[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 16) 0           add_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 112, 112, 16) 0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 112, 112, 8)  136         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 112, 112, 4)  68          max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 112, 112, 16) 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 112, 112, 4)  68          max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 112, 112, 17) 1241        conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 112, 112, 8)  808         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 112, 112, 3)  51          max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 112, 112, 32) 0           conv2d_8[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 112, 112, 32) 544         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 112, 112, 32) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 112, 112, 32) 0           conv2d_14[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 112, 112, 32) 0           add_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 56, 56, 32)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 56, 56, 16)   528         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 8)    264         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 56, 56, 32)   0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 9)    297         max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 33)   4785        conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 56, 56, 16)   3216        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 56, 56, 6)    198         max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 64)   0           conv2d_15[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 56, 56, 64)   2112        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 56, 56, 64)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 64)   0           conv2d_21[0][0]
#                                                                  dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 56, 56, 64)   0           add_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 28, 28, 64)   0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 32)   2080        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 16)   1040        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 28, 28, 64)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 19)   1235        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 65)   18785       conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 32)   12832       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 12)   780         max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 28, 28, 128)  0           conv2d_22[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 128)  8320        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 28, 28, 128)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 128)  0           conv2d_28[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 128)  0           add_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 14, 14, 128)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 64)   8256        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 32)   4128        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 128)  0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 38)   4902        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 129)  74433       conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 25)   3225        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 14, 14, 256)  0           conv2d_29[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 256)  33024       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 14, 14, 256)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 256)  0           conv2d_35[0][0]
#                                                                  dropout_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 14, 14, 256)  0           add_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 7, 7, 256)    0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 7, 7, 128)    32896       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 7, 7, 64)     16448       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 7, 7, 256)    0           max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 7, 7, 76)     19532       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 7, 7, 257)    296321      conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 7, 7, 128)    204928      conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 7, 7, 51)     13107       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 7, 7, 512)    0           conv2d_36[0][0]
#                                                                  conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 7, 7, 512)    131584      max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 7, 7, 512)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 7, 7, 512)    0           conv2d_42[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 7, 7, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 14, 14, 512)  1049088     activation_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 14, 14, 512)  0           conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 14, 14, 768)  0           dropout_7[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 64)   49216       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 14, 14, 32)   24608       concatenate_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 14, 14, 768)  0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 38)   29222       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 14, 14, 129)  74433       conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 14, 14, 25)   19225       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 14, 14, 256)  0           conv2d_43[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 14, 14, 256)  196864      concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 14, 14, 256)  0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 256)  0           conv2d_49[0][0]
#                                                                  dropout_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 256)  0           add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 28, 28, 256)  262400      activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 28, 28, 256)  0           conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 28, 28, 384)  0           dropout_9[0][0]
#                                                                  activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 28, 28, 32)   12320       concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 28, 28, 16)   6160        concatenate_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 28, 28, 384)  0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 28, 28, 19)   7315        concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 28, 28, 65)   18785       conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 28, 28, 32)   12832       conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 28, 28, 12)   4620        max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 28, 28, 128)  0           conv2d_50[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 28, 28, 128)  49280       concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 28, 28, 128)  0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 28, 28, 128)  0           conv2d_56[0][0]
#                                                                  dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 128)  0           add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 56, 56, 128)  65664       activation_8[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 56, 56, 128)  0           conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 56, 56, 192)  0           dropout_11[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 56, 56, 16)   3088        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 56, 56, 8)    1544        concatenate_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 56, 56, 192)  0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 56, 56, 9)    1737        concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 56, 56, 33)   4785        conv2d_58[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 56, 56, 16)   3216        conv2d_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 56, 56, 6)    1158        max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 56, 56, 64)   0           conv2d_57[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 64)   12352       concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 56, 56, 64)   0           concatenate_12[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 56, 56, 64)   0           conv2d_63[0][0]
#                                                                  dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 56, 56, 64)   0           add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 112, 112, 64) 16448       activation_9[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 112, 112, 64) 0           conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 112, 112, 96) 0           dropout_13[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 112, 112, 8)  776         concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 112, 112, 4)  388         concatenate_13[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 112, 112, 96) 0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 112, 112, 4)  388         concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 112, 112, 17) 1241        conv2d_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 112, 112, 8)  808         conv2d_66[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 112, 112, 3)  291         max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 112, 112, 32) 0           conv2d_64[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
#                                                                  conv2d_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 112, 112, 32) 3104        concatenate_13[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 112, 112, 32) 0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 112, 112, 32) 0           conv2d_70[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 112, 112, 32) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 224, 224, 32) 4128        activation_10[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 224, 224, 32) 0           conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 224, 224, 48) 0           dropout_15[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 224, 224, 4)  196         concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 224, 224, 2)  98          concatenate_15[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 224, 224, 48) 0           concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 224, 224, 2)  98          concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 224, 224, 9)  333         conv2d_72[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 224, 224, 4)  204         conv2d_73[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 224, 224, 1)  49          max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 224, 224, 16) 0           conv2d_71[0][0]
#                                                                  conv2d_74[0][0]
#                                                                  conv2d_75[0][0]
#                                                                  conv2d_76[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 224, 224, 16) 784         concatenate_15[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 224, 224, 16) 0           concatenate_16[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 224, 224, 16) 0           conv2d_77[0][0]
#                                                                  dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 224, 224, 16) 0           add_11[0][0]
# __________________________________________________________________________________________________
# st1_out (Conv2D)                (None, 224, 224, 1)  17          activation_11[0][0]
# ==================================================================================================
# Total params: 2,944,600
# Trainable params: 2,944,600
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# *Update: Changed to ELU units, added dropout.*
#
# Next we fit the model on the training data, using a validation split of 0.1. We use a small batch size because we have so little data. I recommend using checkpointing and early stopping when training your model. I won't do it here to make things a bit more reproducible (although it's very likely that your results will be different anyway). I'll just train for 10 epochs, which takes around 10 minutes in the Kaggle kernel with the current parameters.
#
# *Update: Added early stopping and checkpointing and increased to 30 epochs.*

# %%
from keras.preprocessing.image import ImageDataGenerator
import cv2

from sklearn.utils import shuffle
def data_generator(data, label, batch_size=4, training=True):
    index = 0
    dat_que = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
    lab_que = np.empty((batch_size, IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    while True:
        img = data[index%len(data)] # [0,255]
        lab = label[index%len(data)]
        if training:
            if np.random.rand() < .5: # flip vertical
                img = np.flip(img, 0)
                lab = np.flip(lab, 0)
            if np.random.rand() < .5: # flip horizontal
                img = np.flip(img, 1)
                lab = np.flip(lab, 1)

            # rotation
            if np.random.rand() < 0.5:
                y, x, _ = img.shape
                h, w = y, x
                img = cv2.copyMakeBorder(img, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                lab = cv2.copyMakeBorder(lab, y//2, y//2, x//2, x//2, cv2.BORDER_REFLECT)
                y, x, _ = img.shape
                rotT = np.random.uniform(-15,15)
                M = cv2.getRotationMatrix2D((x/2, y/2), rotT, 1)
                img = cv2.warpAffine(img, M, (x, y))
                lab = cv2.warpAffine(lab, M, (x, y))
                img = img[h//2:h//2+h,w//2:w//2+w,:]
                lab = lab[h//2:h//2+h,w//2:w//2+w]

            img = img.astype(np.float32) / 255. # normalize

            # random amplify each channel
            a = .1 # amptitude
            t  = [np.random.uniform(-a,a)]
            t += [np.random.uniform(-a,a)]
            t += [np.random.uniform(-a,a)]
            t = np.array(t)

            img = img * (1. + t) # channel wise amplify
            up = np.random.uniform(0.95, 1.05) # change gamma
            img = img**up * 255. # apply gamma and convert back to range [0,255]
            img = img.astype(np.uint8) # convert back to uint8

            assert img.dtype == np.uint8 ## check type
            assert lab.dtype == np.uint8

            if np.random.rand() < .1: # randomly crop image
                s = np.random.uniform(0.8, 1.2) # random crop scale
                w, h = int(s*IMG_WIDTH), int(s*IMG_HEIGHT)
                paddx = max(0, w-img.shape[1])
                paddy = max(0, h-img.shape[0])
                img = cv2.copyMakeBorder(img, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                lab = cv2.copyMakeBorder(lab, paddy//2, paddy-paddy//2, paddx//2, paddx-paddx//2, cv2.BORDER_REFLECT)
                cropx = img.shape[1] - w + 1
                cropy = img.shape[0] - h + 1
                offx = np.random.randint(0, cropx)
                offy = np.random.randint(0, cropy)
                img = img[offy:offy+h, offx:offx+w, :]
                lab = lab[offy:offy+h, offx:offx+w]
        ### end of data augmentation ###
        
        img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        lab = resize(lab, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
        
        lab[lab<130] = 0
        lab[lab>0] = 1
        
        dat_que[index%batch_size,:,:,:] = img
        lab_que[index%batch_size,:,:,0] = lab
        index = index + 1
        if index%batch_size==0:
            index = 0 if index%len(data)==0 else index
            yield (dat_que, lab_que)
        if training and index%len(data)==0:
            data, label = shuffle(data, label)

from sklearn.model_selection import train_test_split

X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, shuffle=True)

# Fit model
BS=16
EPOCHS=60
earlystopper = EarlyStopping(patience=7, verbose=1)
checkpointer = ModelCheckpoint('model-dsbowl2018-1.h5', verbose=1, save_best_only=True)
history = model.fit_generator(data_generator(X_train, Y_train, batch_size=BS, training=True),
                              steps_per_epoch=len(X_train) // BS , epochs=EPOCHS, 
                              validation_data=data_generator(X_val, Y_val, batch_size=BS, training=False), 
                              validation_steps=len(X_val) // BS,
                    callbacks=[earlystopper, checkpointer])
# Out:
# Epoch 1/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.2993 - mean_iou: 0.4366Epoch 00001: val_loss improved from inf to 0.19823, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 75s 2s/step - loss: 0.2962 - mean_iou: 0.4387 - val_loss: 0.1982 - val_mean_iou: 0.5336
# Epoch 2/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.1380 - mean_iou: 0.5934Epoch 00002: val_loss improved from 0.19823 to 0.13331, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 51s 1s/step - loss: 0.1385 - mean_iou: 0.5943 - val_loss: 0.1333 - val_mean_iou: 0.6310
# Epoch 3/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.1128 - mean_iou: 0.6608Epoch 00003: val_loss improved from 0.13331 to 0.10425, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.1109 - mean_iou: 0.6614 - val_loss: 0.1042 - val_mean_iou: 0.6863
# Epoch 4/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.1003 - mean_iou: 0.7014Epoch 00004: val_loss improved from 0.10425 to 0.10375, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.0998 - mean_iou: 0.7018 - val_loss: 0.1037 - val_mean_iou: 0.7170
# Epoch 5/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.1027 - mean_iou: 0.7279Epoch 00005: val_loss did not improve
# 37/37 [==============================] - 55s 1s/step - loss: 0.1030 - mean_iou: 0.7281 - val_loss: 0.1095 - val_mean_iou: 0.7363
# Epoch 6/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0951 - mean_iou: 0.7421Epoch 00006: val_loss did not improve
# 37/37 [==============================] - 57s 2s/step - loss: 0.0943 - mean_iou: 0.7423 - val_loss: 0.1056 - val_mean_iou: 0.7494
# Epoch 7/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0907 - mean_iou: 0.7560Epoch 00007: val_loss improved from 0.10375 to 0.09566, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0901 - mean_iou: 0.7561 - val_loss: 0.0957 - val_mean_iou: 0.7622
# Epoch 8/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0885 - mean_iou: 0.7665Epoch 00008: val_loss improved from 0.09566 to 0.09158, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.0893 - mean_iou: 0.7666 - val_loss: 0.0916 - val_mean_iou: 0.7707
# Epoch 9/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0864 - mean_iou: 0.7745Epoch 00009: val_loss did not improve
# 37/37 [==============================] - 57s 2s/step - loss: 0.0867 - mean_iou: 0.7746 - val_loss: 0.0941 - val_mean_iou: 0.7782
# Epoch 10/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0837 - mean_iou: 0.7817Epoch 00010: val_loss improved from 0.09158 to 0.08250, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0845 - mean_iou: 0.7817 - val_loss: 0.0825 - val_mean_iou: 0.7845
# Epoch 11/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0770 - mean_iou: 0.7881Epoch 00011: val_loss did not improve
# 37/37 [==============================] - 57s 2s/step - loss: 0.0771 - mean_iou: 0.7882 - val_loss: 0.0880 - val_mean_iou: 0.7910
# Epoch 12/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0756 - mean_iou: 0.7939Epoch 00012: val_loss improved from 0.08250 to 0.07978, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 60s 2s/step - loss: 0.0752 - mean_iou: 0.7939 - val_loss: 0.0798 - val_mean_iou: 0.7964
# Epoch 13/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0789 - mean_iou: 0.7984Epoch 00013: val_loss did not improve
# 37/37 [==============================] - 55s 1s/step - loss: 0.0783 - mean_iou: 0.7984 - val_loss: 0.0822 - val_mean_iou: 0.8006
# Epoch 14/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0763 - mean_iou: 0.8027Epoch 00014: val_loss improved from 0.07978 to 0.07843, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.0764 - mean_iou: 0.8027 - val_loss: 0.0784 - val_mean_iou: 0.8045
# Epoch 15/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0808 - mean_iou: 0.8064Epoch 00015: val_loss did not improve
# 37/37 [==============================] - 58s 2s/step - loss: 0.0803 - mean_iou: 0.8065 - val_loss: 0.0805 - val_mean_iou: 0.8080
# Epoch 16/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0721 - mean_iou: 0.8095Epoch 00016: val_loss improved from 0.07843 to 0.07841, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0717 - mean_iou: 0.8096 - val_loss: 0.0784 - val_mean_iou: 0.8111
# Epoch 17/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0786 - mean_iou: 0.8125Epoch 00017: val_loss did not improve
# 37/37 [==============================] - 57s 2s/step - loss: 0.0778 - mean_iou: 0.8126 - val_loss: 0.0786 - val_mean_iou: 0.8137
# Epoch 18/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0724 - mean_iou: 0.8150Epoch 00018: val_loss did not improve
# 37/37 [==============================] - 57s 2s/step - loss: 0.0731 - mean_iou: 0.8150 - val_loss: 0.0787 - val_mean_iou: 0.8163
# Epoch 19/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0751 - mean_iou: 0.8173Epoch 00019: val_loss did not improve
# 37/37 [==============================] - 58s 2s/step - loss: 0.0753 - mean_iou: 0.8173 - val_loss: 0.0880 - val_mean_iou: 0.8183
# Epoch 20/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0779 - mean_iou: 0.8192Epoch 00020: val_loss improved from 0.07841 to 0.07585, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.0780 - mean_iou: 0.8193 - val_loss: 0.0758 - val_mean_iou: 0.8202
# Epoch 21/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0748 - mean_iou: 0.8209Epoch 00021: val_loss improved from 0.07585 to 0.07552, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 57s 2s/step - loss: 0.0749 - mean_iou: 0.8209 - val_loss: 0.0755 - val_mean_iou: 0.8219
# Epoch 22/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0726 - mean_iou: 0.8229Epoch 00022: val_loss improved from 0.07552 to 0.07446, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0723 - mean_iou: 0.8229 - val_loss: 0.0745 - val_mean_iou: 0.8238
# Epoch 23/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0662 - mean_iou: 0.8248Epoch 00023: val_loss did not improve
# 37/37 [==============================] - 57s 2s/step - loss: 0.0659 - mean_iou: 0.8248 - val_loss: 0.0768 - val_mean_iou: 0.8257
# Epoch 24/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0773 - mean_iou: 0.8262Epoch 00024: val_loss improved from 0.07446 to 0.07178, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 64s 2s/step - loss: 0.0771 - mean_iou: 0.8262 - val_loss: 0.0718 - val_mean_iou: 0.8269
# Epoch 25/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0717 - mean_iou: 0.8277Epoch 00025: val_loss did not improve
# 37/37 [==============================] - 54s 1s/step - loss: 0.0718 - mean_iou: 0.8277 - val_loss: 0.0834 - val_mean_iou: 0.8285
# Epoch 26/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0720 - mean_iou: 0.8289Epoch 00026: val_loss did not improve
# 37/37 [==============================] - 59s 2s/step - loss: 0.0726 - mean_iou: 0.8289 - val_loss: 0.0764 - val_mean_iou: 0.8295
# Epoch 27/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0712 - mean_iou: 0.8302Epoch 00027: val_loss did not improve
# 37/37 [==============================] - 56s 2s/step - loss: 0.0709 - mean_iou: 0.8302 - val_loss: 0.0719 - val_mean_iou: 0.8308
# Epoch 28/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0711 - mean_iou: 0.8313Epoch 00028: val_loss did not improve
# 37/37 [==============================] - 58s 2s/step - loss: 0.0711 - mean_iou: 0.8313 - val_loss: 0.0729 - val_mean_iou: 0.8320
# Epoch 29/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0668 - mean_iou: 0.8326Epoch 00029: val_loss improved from 0.07178 to 0.06997, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 59s 2s/step - loss: 0.0666 - mean_iou: 0.8327 - val_loss: 0.0700 - val_mean_iou: 0.8333
# Epoch 30/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0681 - mean_iou: 0.8340Epoch 00030: val_loss improved from 0.06997 to 0.06984, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 56s 2s/step - loss: 0.0675 - mean_iou: 0.8340 - val_loss: 0.0698 - val_mean_iou: 0.8344
# Epoch 31/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0692 - mean_iou: 0.8350Epoch 00031: val_loss improved from 0.06984 to 0.06789, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.0688 - mean_iou: 0.8350 - val_loss: 0.0679 - val_mean_iou: 0.8356
# Epoch 32/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0759 - mean_iou: 0.8360Epoch 00032: val_loss did not improve
# 37/37 [==============================] - 56s 2s/step - loss: 0.0757 - mean_iou: 0.8360 - val_loss: 0.0705 - val_mean_iou: 0.8364
# Epoch 33/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0616 - mean_iou: 0.8368Epoch 00033: val_loss improved from 0.06789 to 0.06386, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 58s 2s/step - loss: 0.0624 - mean_iou: 0.8369 - val_loss: 0.0639 - val_mean_iou: 0.8375
# Epoch 34/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0691 - mean_iou: 0.8380Epoch 00034: val_loss did not improve
# 37/37 [==============================] - 56s 2s/step - loss: 0.0685 - mean_iou: 0.8380 - val_loss: 0.0705 - val_mean_iou: 0.8383
# Epoch 35/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0704 - mean_iou: 0.8386Epoch 00035: val_loss did not improve
# 37/37 [==============================] - 59s 2s/step - loss: 0.0707 - mean_iou: 0.8387 - val_loss: 0.0776 - val_mean_iou: 0.8390
# Epoch 36/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0682 - mean_iou: 0.8394Epoch 00036: val_loss did not improve
# 37/37 [==============================] - 57s 2s/step - loss: 0.0678 - mean_iou: 0.8394 - val_loss: 0.0725 - val_mean_iou: 0.8398
# Epoch 37/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0633 - mean_iou: 0.8403Epoch 00037: val_loss improved from 0.06386 to 0.06241, saving model to model-dsbowl2018-1.h5
# 37/37 [==============================] - 55s 1s/step - loss: 0.0637 - mean_iou: 0.8403 - val_loss: 0.0624 - val_mean_iou: 0.8407
# Epoch 38/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0644 - mean_iou: 0.8411Epoch 00038: val_loss did not improve
# 37/37 [==============================] - 57s 2s/step - loss: 0.0639 - mean_iou: 0.8411 - val_loss: 0.0706 - val_mean_iou: 0.8416
# Epoch 39/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0679 - mean_iou: 0.8419Epoch 00039: val_loss did not improve
# 37/37 [==============================] - 59s 2s/step - loss: 0.0685 - mean_iou: 0.8419 - val_loss: 0.0675 - val_mean_iou: 0.8422
# Epoch 40/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0630 - mean_iou: 0.8426Epoch 00040: val_loss did not improve
# 37/37 [==============================] - 54s 1s/step - loss: 0.0625 - mean_iou: 0.8426 - val_loss: 0.0721 - val_mean_iou: 0.8431
# Epoch 41/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0649 - mean_iou: 0.8435Epoch 00041: val_loss did not improve
# 37/37 [==============================] - 59s 2s/step - loss: 0.0655 - mean_iou: 0.8435 - val_loss: 0.0694 - val_mean_iou: 0.8437
# Epoch 42/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0629 - mean_iou: 0.8442Epoch 00042: val_loss did not improve
# 37/37 [==============================] - 57s 2s/step - loss: 0.0629 - mean_iou: 0.8442 - val_loss: 0.0685 - val_mean_iou: 0.8445
# Epoch 43/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0635 - mean_iou: 0.8449Epoch 00043: val_loss did not improve
# 37/37 [==============================] - 57s 2s/step - loss: 0.0632 - mean_iou: 0.8449 - val_loss: 0.0668 - val_mean_iou: 0.8452
# Epoch 44/60
# 36/37 [============================>.] - ETA: 1s - loss: 0.0623 - mean_iou: 0.8455Epoch 00044: val_loss did not improve
# 37/37 [==============================] - 58s 2s/step - loss: 0.0633 - mean_iou: 0.8455 - val_loss: 0.0668 - val_mean_iou: 0.8459
# Epoch 00044: early stopping

# %%
plt.plot(history.history['mean_iou'])
plt.plot(history.history['val_mean_iou'])
plt.title('model mean_iou')
plt.ylabel('mean_iou')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','valid'], loc='upper right')
plt.show()

# %% [markdown]
# All right, looks good! Loss seems to be a bit erratic, though. I'll leave it to you to improve the model architecture and parameters!
#
# # Make predictions
#
# Let's make predictions both on the test set, the val set and the train set (as a sanity check). Remember to load the best saved model if you've used early stopping and checkpointing.

# %%
from skimage.morphology import closing, square, remove_small_objects
from skimage.segmentation import clear_border

# Predict on train, val and test
model = load_model('model-dsbowl2018-1.h5', custom_objects={'mean_iou': mean_iou})
preds_train = model.predict_generator(data_generator(X_train, Y_train, batch_size=1, training=False), steps=len(X_train), verbose=1)
preds_val = model.predict_generator(data_generator(X_val, Y_val, batch_size=1, training=False), steps=len(X_val), verbose=1)
preds_test = model.predict(X_test, verbose=1)

def cleaning(imgs):
    for i, img in enumerate(imgs):
        img = np.squeeze(img)
        imgs[i,:,:,0] = remove_small_objects(img, min_size=4)
    return imgs

# Threshold predictions
preds_train_t = cleaning((preds_train > 0.5).astype(np.uint8))
preds_val_t = cleaning((preds_val > 0.5).astype(np.uint8))
preds_test_t = cleaning((preds_test > 0.5).astype(np.uint8))

# Create list of upsampled test masks
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (sizes_test[i][0], sizes_test[i][1]), 
                                       mode='constant', preserve_range=True))
# Out:
# 603/603 [==============================] - 25s 42ms/step
# 67/67 [==============================] - 3s 43ms/step
# 65/65 [==============================] - 1s 11ms/step

# %%
# Perform a sanity check on some random training samples
ix = random.randint(0, len(preds_train_t))
print(ix)
shape = Y_train[ix].shape[:2]
plt.imshow(X_train[ix])
plt.show()
plt.imshow(np.squeeze(Y_train[ix]))
plt.show()
plt.imshow(resize(np.squeeze(preds_train_t[ix]), shape))
plt.show()
# Out:
# 403

# %% [markdown]
# The model is at least able to fit to the training data! Certainly a lot of room for improvement even here, but a decent start. How about the validation data?

# %%
# Perform a sanity check on some random validation samples
ix = random.randint(0, len(preds_val_t))
print(ix)
shape = Y_val[ix].shape[:2]
plt.imshow(X_val[ix])
plt.show()
plt.imshow(np.squeeze(Y_val[ix]))
plt.show()
plt.imshow(resize(np.squeeze(preds_val_t[ix]), shape))
plt.show()
# Out:
# 44

# %% [markdown]
# Not too shabby! Definitely needs some more training and tweaking.
#
# # Encode and submit our results
#
# Now it's time to submit our results. I've stolen [this](https://www.kaggle.com/rakhlin/fast-run-length-encoding-python) excellent implementation of run-length encoding.

# %%
# Run-length encoding stolen from https://www.kaggle.com/rakhlin/fast-run-length-encoding-python
def rle_encoding(x):
    dots = np.where(x.T.flatten() == 1)[0]
    run_lengths = []
    prev = -2
    for b in dots:
        if (b>prev+1): run_lengths.extend((b + 1, 0))
        run_lengths[-1] += 1
        prev = b
    return run_lengths

def prob_to_rles(x, cutoff=0.5):
    lab_img = label(x > cutoff)
    for i in range(1, lab_img.max() + 1):
        yield rle_encoding(lab_img == i)

# %% [markdown]
# Let's iterate over the test IDs and generate run-length encodings for each seperate mask identified by skimage ...

# %%
new_test_ids = []
rles = []
for n, id_ in enumerate(test_ids):
    rle = list(prob_to_rles(preds_test_upsampled[n]))
    rles.extend(rle)
    new_test_ids.extend([id_] * len(rle))

# %% [markdown]
# ... and then finally create our submission!

# %%
# Create submission DataFrame
sub = pd.DataFrame()
sub['ImageId'] = new_test_ids
sub['EncodedPixels'] = pd.Series(rles).apply(lambda x: ' '.join(str(y) for y in x))
sub.to_csv('sub-dsbowl2018-1.csv', index=False)

# %% [markdown]
# This scored 0.233 on the LB for me. That was with version 2 of this notebook; be aware that the results from the neural network are extremely erratic and vary greatly from run to run (version 3 is significantly worse, for example). Version 7 scores 0.277!
#
# You should easily be able to stabilize and improve the results just by changing a few parameters, tweaking the architecture a little bit and training longer with early stopping.
#
# **Have fun!**
#
# LB score history:
# - Version 7: 0.277 LB

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png', show_shapes=True)
